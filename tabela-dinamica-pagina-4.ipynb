# %%
import pandas as pd
import numpy as np

# %%
# Página 4 (https://swapi.dev/api/people/?page=4)
# capturando a lista de pessoas, para compor a tabela:

# %%
results_page_4 = [
     {
            "name": "Qui-Gon Jinn", 
            "height": "193", 
            "mass": "89", 
            "hair_color": "brown", 
            "skin_color": "fair", 
            "eye_color": "blue", 
            "birth_year": "92BBY", 
            "gender": "male", 
            "homeworld": "https://swapi.dev/api/planets/28/", 
            "films": [
                "https://swapi.dev/api/films/4/"
            ], 
            "species": [], 
            "vehicles": [
                "https://swapi.dev/api/vehicles/38/"
            ], 
            "starships": [], 
            "created": "2014-12-19T16:54:53.618000Z", 
            "edited": "2014-12-20T21:17:50.375000Z", 
            "url": "https://swapi.dev/api/people/32/"
        }, 
        {
            "name": "Nute Gunray", 
            "height": "191", 
            "mass": "90", 
            "hair_color": "none", 
            "skin_color": "mottled green", 
            "eye_color": "red", 
            "birth_year": "unknown", 
            "gender": "male", 
            "homeworld": "https://swapi.dev/api/planets/18/", 
            "films": [
                "https://swapi.dev/api/films/4/", 
                "https://swapi.dev/api/films/5/", 
                "https://swapi.dev/api/films/6/"
            ], 
            "species": [
                "https://swapi.dev/api/species/11/"
            ], 
            "vehicles": [], 
            "starships": [], 
            "created": "2014-12-19T17:05:57.357000Z", 
            "edited": "2014-12-20T21:17:50.377000Z", 
            "url": "https://swapi.dev/api/people/33/"
        }, 
        {
            "name": "Finis Valorum", 
            "height": "170", 
            "mass": "unknown", 
            "hair_color": "blond", 
            "skin_color": "fair", 
            "eye_color": "blue", 
            "birth_year": "91BBY", 
            "gender": "male", 
            "homeworld": "https://swapi.dev/api/planets/9/", 
            "films": [
                "https://swapi.dev/api/films/4/"
            ], 
            "species": [], 
            "vehicles": [], 
            "starships": [], 
            "created": "2014-12-19T17:21:45.915000Z", 
            "edited": "2014-12-20T21:17:50.379000Z", 
            "url": "https://swapi.dev/api/people/34/"
        }, 
        {
            "name": "Padmé Amidala", 
            "height": "185", 
            "mass": "45", 
            "hair_color": "brown", 
            "skin_color": "light", 
            "eye_color": "brown", 
            "birth_year": "46BBY", 
            "gender": "female", 
            "homeworld": "https://swapi.dev/api/planets/8/", 
            "films": [
                "https://swapi.dev/api/films/4/", 
                "https://swapi.dev/api/films/5/", 
                "https://swapi.dev/api/films/6/"
            ], 
            "species": [], 
            "vehicles": [], 
            "starships": [
                "https://swapi.dev/api/starships/39/", 
                "https://swapi.dev/api/starships/49/", 
                "https://swapi.dev/api/starships/64/"
            ], 
            "created": "2014-12-19T17:28:26.926000Z", 
            "edited": "2014-12-20T21:17:50.381000Z", 
            "url": "https://swapi.dev/api/people/35/"
        }, 
        {
            "name": "Jar Jar Binks", 
            "height": "196", 
            "mass": "66", 
            "hair_color": "none", 
            "skin_color": "orange", 
            "eye_color": "orange", 
            "birth_year": "52BBY", 
            "gender": "male", 
            "homeworld": "https://swapi.dev/api/planets/8/", 
            "films": [
                "https://swapi.dev/api/films/4/", 
                "https://swapi.dev/api/films/5/"
            ], 
            "species": [
                "https://swapi.dev/api/species/12/"
            ], 
            "vehicles": [], 
            "starships": [], 
            "created": "2014-12-19T17:29:32.489000Z", 
            "edited": "2014-12-20T21:17:50.383000Z", 
            "url": "https://swapi.dev/api/people/36/"
        }, 
        {
            "name": "Roos Tarpals", 
            "height": "224", 
            "mass": "82", 
            "hair_color": "none", 
            "skin_color": "grey", 
            "eye_color": "orange", 
            "birth_year": "unknown", 
            "gender": "male", 
            "homeworld": "https://swapi.dev/api/planets/8/", 
            "films": [
                "https://swapi.dev/api/films/4/"
            ], 
            "species": [
                "https://swapi.dev/api/species/12/"
            ], 
            "vehicles": [], 
            "starships": [], 
            "created": "2014-12-19T17:32:56.741000Z", 
            "edited": "2014-12-20T21:17:50.385000Z", 
            "url": "https://swapi.dev/api/people/37/"
        }, 
        {
            "name": "Rugor Nass", 
            "height": "206", 
            "mass": "unknown", 
            "hair_color": "none", 
            "skin_color": "green", 
            "eye_color": "orange", 
            "birth_year": "unknown", 
            "gender": "male", 
            "homeworld": "https://swapi.dev/api/planets/8/", 
            "films": [
                "https://swapi.dev/api/films/4/"
            ], 
            "species": [
                "https://swapi.dev/api/species/12/"
            ], 
            "vehicles": [], 
            "starships": [], 
            "created": "2014-12-19T17:33:38.909000Z", 
            "edited": "2014-12-20T21:17:50.388000Z", 
            "url": "https://swapi.dev/api/people/38/"
        }, 
        {
            "name": "Ric Olié", 
            "height": "183", 
            "mass": "unknown", 
            "hair_color": "brown", 
            "skin_color": "fair", 
            "eye_color": "blue", 
            "birth_year": "unknown", 
            "gender": "male", 
            "homeworld": "https://swapi.dev/api/planets/8/", 
            "films": [
                "https://swapi.dev/api/films/4/"
            ], 
            "species": [], 
            "vehicles": [], 
            "starships": [
                "https://swapi.dev/api/starships/40/"
            ], 
            "created": "2014-12-19T17:45:01.522000Z", 
            "edited": "2014-12-20T21:17:50.392000Z", 
            "url": "https://swapi.dev/api/people/39/"
        }, 
        {
            "name": "Watto", 
            "height": "137", 
            "mass": "unknown", 
            "hair_color": "black", 
            "skin_color": "blue, grey", 
            "eye_color": "yellow", 
            "birth_year": "unknown", 
            "gender": "male", 
            "homeworld": "https://swapi.dev/api/planets/34/", 
            "films": [
                "https://swapi.dev/api/films/4/", 
                "https://swapi.dev/api/films/5/"
            ], 
            "species": [
                "https://swapi.dev/api/species/13/"
            ], 
            "vehicles": [], 
            "starships": [], 
            "created": "2014-12-19T17:48:54.647000Z", 
            "edited": "2014-12-20T21:17:50.395000Z", 
            "url": "https://swapi.dev/api/people/40/"
        }, 
        {
            "name": "Sebulba", 
            "height": "112", 
            "mass": "40", 
            "hair_color": "none", 
            "skin_color": "grey, red", 
            "eye_color": "orange", 
            "birth_year": "unknown", 
            "gender": "male", 
            "homeworld": "https://swapi.dev/api/planets/35/", 
            "films": [
                "https://swapi.dev/api/films/4/"
            ], 
            "species": [
                "https://swapi.dev/api/species/14/"
            ], 
            "vehicles": [], 
            "starships": [], 
            "created": "2014-12-19T17:53:02.586000Z", 
            "edited": "2014-12-20T21:17:50.397000Z", 
            "url": "https://swapi.dev/api/people/41/"
        }
    ]

# %%
# Página 4
# transformando os dados em dataframe:

# %%
df = pd.DataFrame(results_page_4)

print(df)
# Out:
#             name height     mass hair_color     skin_color eye_color  \
# 0   Qui-Gon Jinn    193       89      brown           fair      blue
# 1    Nute Gunray    191       90       none  mottled green       red
# 2  Finis Valorum    170  unknown      blond           fair      blue
# 3  Padmé Amidala    185       45      brown          light     brown
# 4  Jar Jar Binks    196       66       none         orange    orange
# 5   Roos Tarpals    224       82       none           grey    orange
# 6     Rugor Nass    206  unknown       none          green    orange
# 7       Ric Olié    183  unknown      brown           fair      blue
# 8          Watto    137  unknown      black     blue, grey    yellow
# 9        Sebulba    112       40       none      grey, red    orange
#
#   birth_year  gender                          homeworld  \
# 0      92BBY    male  https://swapi.dev/api/planets/28/
# 1    unknown    male  https://swapi.dev/api/planets/18/
# 2      91BBY    male   https://swapi.dev/api/planets/9/
# 3      46BBY  female   https://swapi.dev/api/planets/8/
# 4      52BBY    male   https://swapi.dev/api/planets/8/
# 5    unknown    male   https://swapi.dev/api/planets/8/
# 6    unknown    male   https://swapi.dev/api/planets/8/
# 7    unknown    male   https://swapi.dev/api/planets/8/
# 8    unknown    male  https://swapi.dev/api/planets/34/
# 9    unknown    male  https://swapi.dev/api/planets/35/
#
#                                                films  \
# 0                   [https://swapi.dev/api/films/4/]
# 1  [https://swapi.dev/api/films/4/, https://swapi...
# 2                   [https://swapi.dev/api/films/4/]
# 3  [https://swapi.dev/api/films/4/, https://swapi...
# 4  [https://swapi.dev/api/films/4/, https://swapi...
# 5                   [https://swapi.dev/api/films/4/]
# 6                   [https://swapi.dev/api/films/4/]
# 7                   [https://swapi.dev/api/films/4/]
# 8  [https://swapi.dev/api/films/4/, https://swapi...
# 9                   [https://swapi.dev/api/films/4/]
#
#                                species                              vehicles  \
# 0                                   []  [https://swapi.dev/api/vehicles/38/]
# 1  [https://swapi.dev/api/species/11/]                                    []
# 2                                   []                                    []
# 3                                   []                                    []
# 4  [https://swapi.dev/api/species/12/]                                    []
# 5  [https://swapi.dev/api/species/12/]                                    []
# 6  [https://swapi.dev/api/species/12/]                                    []
# 7                                   []                                    []
# 8  [https://swapi.dev/api/species/13/]                                    []
# 9  [https://swapi.dev/api/species/14/]                                    []
#
#                                            starships  \
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3  [https://swapi.dev/api/starships/39/, https://...
# 4                                                 []
# 5                                                 []
# 6                                                 []
# 7              [https://swapi.dev/api/starships/40/]
# 8                                                 []
# 9                                                 []
#
#                        created                       edited  \
# 0  2014-12-19T16:54:53.618000Z  2014-12-20T21:17:50.375000Z
# 1  2014-12-19T17:05:57.357000Z  2014-12-20T21:17:50.377000Z
# 2  2014-12-19T17:21:45.915000Z  2014-12-20T21:17:50.379000Z
# 3  2014-12-19T17:28:26.926000Z  2014-12-20T21:17:50.381000Z
# 4  2014-12-19T17:29:32.489000Z  2014-12-20T21:17:50.383000Z
# 5  2014-12-19T17:32:56.741000Z  2014-12-20T21:17:50.385000Z
# 6  2014-12-19T17:33:38.909000Z  2014-12-20T21:17:50.388000Z
# 7  2014-12-19T17:45:01.522000Z  2014-12-20T21:17:50.392000Z
# 8  2014-12-19T17:48:54.647000Z  2014-12-20T21:17:50.395000Z
# 9  2014-12-19T17:53:02.586000Z  2014-12-20T21:17:50.397000Z
#
#                                 url
# 0  https://swapi.dev/api/people/32/
# 1  https://swapi.dev/api/people/33/
# 2  https://swapi.dev/api/people/34/
# 3  https://swapi.dev/api/people/35/
# 4  https://swapi.dev/api/people/36/
# 5  https://swapi.dev/api/people/37/
# 6  https://swapi.dev/api/people/38/
# 7  https://swapi.dev/api/people/39/
# 8  https://swapi.dev/api/people/40/
# 9  https://swapi.dev/api/people/41/

# %%
# Página 4
# transformando o dataframe em tabela

# %%
df
# Out:
#             name height     mass hair_color     skin_color eye_color  \
# 0   Qui-Gon Jinn    193       89      brown           fair      blue
# 1    Nute Gunray    191       90       none  mottled green       red
# 2  Finis Valorum    170  unknown      blond           fair      blue
# 3  Padmé Amidala    185       45      brown          light     brown
# 4  Jar Jar Binks    196       66       none         orange    orange
# 5   Roos Tarpals    224       82       none           grey    orange
# 6     Rugor Nass    206  unknown       none          green    orange
# 7       Ric Olié    183  unknown      brown           fair      blue
# 8          Watto    137  unknown      black     blue, grey    yellow
# 9        Sebulba    112       40       none      grey, red    orange
#
#   birth_year  gender                          homeworld  \
# 0      92BBY    male  https://swapi.dev/api/planets/28/
# 1    unknown    male  https://swapi.dev/api/planets/18/
# 2      91BBY    male   https://swapi.dev/api/planets/9/
# 3      46BBY  female   https://swapi.dev/api/planets/8/
# 4      52BBY    male   https://swapi.dev/api/planets/8/
# 5    unknown    male   https://swapi.dev/api/planets/8/
# 6    unknown    male   https://swapi.dev/api/planets/8/
# 7    unknown    male   https://swapi.dev/api/planets/8/
# 8    unknown    male  https://swapi.dev/api/planets/34/
# 9    unknown    male  https://swapi.dev/api/planets/35/
#
#                                                films  \
# 0                   [https://swapi.dev/api/films/4/]
# 1  [https://swapi.dev/api/films/4/, https://swapi...
# 2                   [https://swapi.dev/api/films/4/]
# 3  [https://swapi.dev/api/films/4/, https://swapi...
# 4  [https://swapi.dev/api/films/4/, https://swapi...
# 5                   [https://swapi.dev/api/films/4/]
# 6                   [https://swapi.dev/api/films/4/]
# 7                   [https://swapi.dev/api/films/4/]
# 8  [https://swapi.dev/api/films/4/, https://swapi...
# 9                   [https://swapi.dev/api/films/4/]
#
#                                species                              vehicles  \
# 0                                   []  [https://swapi.dev/api/vehicles/38/]
# 1  [https://swapi.dev/api/species/11/]                                    []
# 2                                   []                                    []
# 3                                   []                                    []
# 4  [https://swapi.dev/api/species/12/]                                    []
# 5  [https://swapi.dev/api/species/12/]                                    []
# 6  [https://swapi.dev/api/species/12/]                                    []
# 7                                   []                                    []
# 8  [https://swapi.dev/api/species/13/]                                    []
# 9  [https://swapi.dev/api/species/14/]                                    []
#
#                                            starships  \
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3  [https://swapi.dev/api/starships/39/, https://...
# 4                                                 []
# 5                                                 []
# 6                                                 []
# 7              [https://swapi.dev/api/starships/40/]
# 8                                                 []
# 9                                                 []
#
#                        created                       edited  \
# 0  2014-12-19T16:54:53.618000Z  2014-12-20T21:17:50.375000Z
# 1  2014-12-19T17:05:57.357000Z  2014-12-20T21:17:50.377000Z
# 2  2014-12-19T17:21:45.915000Z  2014-12-20T21:17:50.379000Z
# 3  2014-12-19T17:28:26.926000Z  2014-12-20T21:17:50.381000Z
# 4  2014-12-19T17:29:32.489000Z  2014-12-20T21:17:50.383000Z
# 5  2014-12-19T17:32:56.741000Z  2014-12-20T21:17:50.385000Z
# 6  2014-12-19T17:33:38.909000Z  2014-12-20T21:17:50.388000Z
# 7  2014-12-19T17:45:01.522000Z  2014-12-20T21:17:50.392000Z
# 8  2014-12-19T17:48:54.647000Z  2014-12-20T21:17:50.395000Z
# 9  2014-12-19T17:53:02.586000Z  2014-12-20T21:17:50.397000Z
#
#                                 url
# 0  https://swapi.dev/api/people/32/
# 1  https://swapi.dev/api/people/33/
# 2  https://swapi.dev/api/people/34/
# 3  https://swapi.dev/api/people/35/
# 4  https://swapi.dev/api/people/36/
# 5  https://swapi.dev/api/people/37/
# 6  https://swapi.dev/api/people/38/
# 7  https://swapi.dev/api/people/39/
# 8  https://swapi.dev/api/people/40/
# 9  https://swapi.dev/api/people/41/

# %%
# Página 4
# selecionando os dados solicitados: nome e cor da pele

# %%
nome_e_cor_da_pele = df[['name', 'skin_color']]
display(nome_e_cor_da_pele)
# Out:
#             name     skin_color
# 0   Qui-Gon Jinn           fair
# 1    Nute Gunray  mottled green
# 2  Finis Valorum           fair
# 3  Padmé Amidala          light
# 4  Jar Jar Binks         orange
# 5   Roos Tarpals           grey
# 6     Rugor Nass          green
# 7       Ric Olié           fair
# 8          Watto     blue, grey
# 9        Sebulba      grey, red

# %%
# Página 4
# Colunas com as propriedades e seus respectivos valores, de acordo com o retorno da api nome , altura, peso, aniversário e gênero.

# %%
nome_altura_peso_aniversario_genero = df[['name', 'height', 'mass', 'birth_year', 'gender' ]]
display(nome_altura_peso_aniversario_genero)
# Out:
#             name height     mass birth_year  gender
# 0   Qui-Gon Jinn    193       89      92BBY    male
# 1    Nute Gunray    191       90    unknown    male
# 2  Finis Valorum    170  unknown      91BBY    male
# 3  Padmé Amidala    185       45      46BBY  female
# 4  Jar Jar Binks    196       66      52BBY    male
# 5   Roos Tarpals    224       82    unknown    male
# 6     Rugor Nass    206  unknown    unknown    male
# 7       Ric Olié    183  unknown    unknown    male
# 8          Watto    137  unknown    unknown    male
# 9        Sebulba    112       40    unknown    male

# %%
# transformando a tabela python completa em uma tabela HTML ( para construir as páginas)

# %%
html=df.to_html()
print(html)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>height</th>
#       <th>mass</th>
#       <th>hair_color</th>
#       <th>skin_color</th>
#       <th>eye_color</th>
#       <th>birth_year</th>
#       <th>gender</th>
#       <th>homeworld</th>
#       <th>films</th>
#       <th>species</th>
#       <th>vehicles</th>
#       <th>starships</th>
#       <th>created</th>
#       <th>edited</th>
#       <th>url</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Qui-Gon Jinn</td>
#       <td>193</td>
#       <td>89</td>
#       <td>brown</td>
#       <td>fair</td>
#       <td>blue</td>
#       <td>92BBY</td>
#       <td>male</td>
#       <td>https://swapi.dev/api/planets/28/</td>
#       <td>[https://swapi.dev/api/films/4/]</td>
#       <td>[]</td>
#       <td>[https://swapi.dev/api/vehicles/38/]</td>
#       <td>[]</td>
#       <td>2014-12-19T16:54:53.618000Z</td>
#       <td>2014-12-20T21:17:50.375000Z</td>
#       <td>https://swapi.dev/api/people/32/</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Nute Gunray</td>
#       <td>191</td>
#       <td>90</td>
#       <td>none</td>
#       <td>mottled green</td>
#       <td>red</td>
#       <td>unknown</td>
#       <td>male</td>
#       <td>https://swapi.dev/api/planets/18/</td>
#       <td>[https://swapi.dev/api/films/4/, https://swapi.dev/api/films/5/, https://swapi.dev/api/films/6/]</td>
#       <td>[https://swapi.dev/api/species/11/]</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>2014-12-19T17:05:57.357000Z</td>
#       <td>2014-12-20T21:17:50.377000Z</td>
#       <td>https://swapi.dev/api/people/33/</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Finis Valorum</td>
#       <td>170</td>
#       <td>unknown</td>
#       <td>blond</td>
#       <td>fair</td>
#       <td>blue</td>
#       <td>91BBY</td>
#       <td>male</td>
#       <td>https://swapi.dev/api/planets/9/</td>
#       <td>[https://swapi.dev/api/films/4/]</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>2014-12-19T17:21:45.915000Z</td>
#       <td>2014-12-20T21:17:50.379000Z</td>
#       <td>https://swapi.dev/api/people/34/</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Padmé Amidala</td>
#       <td>185</td>
#       <td>45</td>
#       <td>brown</td>
#       <td>light</td>
#       <td>brown</td>
#       <td>46BBY</td>
#       <td>female</td>
#       <td>https://swapi.dev/api/planets/8/</td>
#       <td>[https://swapi.dev/api/films/4/, https://swapi.dev/api/films/5/, https://swapi.dev/api/films/6/]</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>[https://swapi.dev/api/starships/39/, https://swapi.dev/api/starships/49/, https://swapi.dev/api/starships/64/]</td>
#       <td>2014-12-19T17:28:26.926000Z</td>
#       <td>2014-12-20T21:17:50.381000Z</td>
#       <td>https://swapi.dev/api/people/35/</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Jar Jar Binks</td>
#       <td>196</td>
#       <td>66</td>
#       <td>none</td>
#       <td>orange</td>
#       <td>orange</td>
#       <td>52BBY</td>
#       <td>male</td>
#       <td>https://swapi.dev/api/planets/8/</td>
#       <td>[https://swapi.dev/api/films/4/, https://swapi.dev/api/films/5/]</td>
#       <td>[https://swapi.dev/api/species/12/]</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>2014-12-19T17:29:32.489000Z</td>
#       <td>2014-12-20T21:17:50.383000Z</td>
#       <td>https://swapi.dev/api/people/36/</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Roos Tarpals</td>
#       <td>224</td>
#       <td>82</td>
#       <td>none</td>
#       <td>grey</td>
#       <td>orange</td>
#       <td>unknown</td>
#       <td>male</td>
#       <td>https://swapi.dev/api/planets/8/</td>
#       <td>[https://swapi.dev/api/films/4/]</td>
#       <td>[https://swapi.dev/api/species/12/]</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>2014-12-19T17:32:56.741000Z</td>
#       <td>2014-12-20T21:17:50.385000Z</td>
#       <td>https://swapi.dev/api/people/37/</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Rugor Nass</td>
#       <td>206</td>
#       <td>unknown</td>
#       <td>none</td>
#       <td>green</td>
#       <td>orange</td>
#       <td>unknown</td>
#       <td>male</td>
#       <td>https://swapi.dev/api/planets/8/</td>
#       <td>[https://swapi.dev/api/films/4/]</td>
#       <td>[https://swapi.dev/api/species/12/]</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>2014-12-19T17:33:38.909000Z</td>
#       <td>2014-12-20T21:17:50.388000Z</td>
#       <td>https://swapi.dev/api/people/38/</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Ric Olié</td>
#       <td>183</td>
#       <td>unknown</td>
#       <td>brown</td>
#       <td>fair</td>
#       <td>blue</td>
#       <td>unknown</td>
#       <td>male</td>
#       <td>https://swapi.dev/api/planets/8/</td>
#       <td>[https://swapi.dev/api/films/4/]</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>[https://swapi.dev/api/starships/40/]</td>
#       <td>2014-12-19T17:45:01.522000Z</td>
#       <td>2014-12-20T21:17:50.392000Z</td>
#       <td>https://swapi.dev/api/people/39/</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Watto</td>
#       <td>137</td>
#       <td>unknown</td>
#       <td>black</td>
#       <td>blue, grey</td>
#       <td>yellow</td>
#       <td>unknown</td>
#       <td>male</td>
#       <td>https://swapi.dev/api/planets/34/</td>
#       <td>[https://swapi.dev/api/films/4/, https://swapi.dev/api/films/5/]</td>
#       <td>[https://swapi.dev/api/species/13/]</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>2014-12-19T17:48:54.647000Z</td>
#       <td>2014-12-20T21:17:50.395000Z</td>
#       <td>https://swapi.dev/api/people/40/</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Sebulba</td>
#       <td>112</td>
#       <td>40</td>
#       <td>none</td>
#       <td>grey, red</td>
#       <td>orange</td>
#       <td>unknown</td>
#       <td>male</td>
#       <td>https://swapi.dev/api/planets/35/</td>
#       <td>[https://swapi.dev/api/films/4/]</td>
#       <td>[https://swapi.dev/api/species/14/]</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>2014-12-19T17:53:02.586000Z</td>
#       <td>2014-12-20T21:17:50.397000Z</td>
#       <td>https://swapi.dev/api/people/41/</td>
#     </tr>
#   </tbody>
# </table>

# %%
#exportando a tabela escrita em html para arquivo html:

# %%
arq = open("tabela_pagina_4.html", "w")
arq = arq.write(html)

# %%
#organizando os dados de cada pessoa

# %%
df.values.tolist()
# Out:
# [['Qui-Gon Jinn',
#   '193',
#   '89',
#   'brown',
#   'fair',
#   'blue',
#   '92BBY',
#   'male',
#   'https://swapi.dev/api/planets/28/',
#   ['https://swapi.dev/api/films/4/'],
#   [],
#   ['https://swapi.dev/api/vehicles/38/'],
#   [],
#   '2014-12-19T16:54:53.618000Z',
#   '2014-12-20T21:17:50.375000Z',
#   'https://swapi.dev/api/people/32/'],
#  ['Nute Gunray',
#   '191',
#   '90',
#   'none',
#   'mottled green',
#   'red',
#   'unknown',
#   'male',
#   'https://swapi.dev/api/planets/18/',
#   ['https://swapi.dev/api/films/4/',
#    'https://swapi.dev/api/films/5/',
#    'https://swapi.dev/api/films/6/'],
#   ['https://swapi.dev/api/species/11/'],
#   [],
#   [],
#   '2014-12-19T17:05:57.357000Z',
#   '2014-12-20T21:17:50.377000Z',
#   'https://swapi.dev/api/people/33/'],
#  ['Finis Valorum',
#   '170',
#   'unknown',
#   'blond',
#   'fair',
#   'blue',
#   '91BBY',
#   'male',
#   'https://swapi.dev/api/planets/9/',
#   ['https://swapi.dev/api/films/4/'],
#   [],
#   [],
#   [],
#   '2014-12-19T17:21:45.915000Z',
#   '2014-12-20T21:17:50.379000Z',
#   'https://swapi.dev/api/people/34/'],
#  ['Padmé Amidala',
#   '185',
#   '45',
#   'brown',
#   'light',
#   'brown',
#   '46BBY',
#   'female',
#   'https://swapi.dev/api/planets/8/',
#   ['https://swapi.dev/api/films/4/',
#    'https://swapi.dev/api/films/5/',
#    'https://swapi.dev/api/films/6/'],
#   [],
#   [],
#   ['https://swapi.dev/api/starships/39/',
#    'https://swapi.dev/api/starships/49/',
#    'https://swapi.dev/api/starships/64/'],
#   '2014-12-19T17:28:26.926000Z',
#   '2014-12-20T21:17:50.381000Z',
#   'https://swapi.dev/api/people/35/'],
#  ['Jar Jar Binks',
#   '196',
#   '66',
#   'none',
#   'orange',
#   'orange',
#   '52BBY',
#   'male',
#   'https://swapi.dev/api/planets/8/',
#   ['https://swapi.dev/api/films/4/', 'https://swapi.dev/api/films/5/'],
#   ['https://swapi.dev/api/species/12/'],
#   [],
#   [],
#   '2014-12-19T17:29:32.489000Z',
#   '2014-12-20T21:17:50.383000Z',
#   'https://swapi.dev/api/people/36/'],
#  ['Roos Tarpals',
#   '224',
#   '82',
#   'none',
#   'grey',
#   'orange',
#   'unknown',
#   'male',
#   'https://swapi.dev/api/planets/8/',
#   ['https://swapi.dev/api/films/4/'],
#   ['https://swapi.dev/api/species/12/'],
#   [],
#   [],
#   '2014-12-19T17:32:56.741000Z',
#   '2014-12-20T21:17:50.385000Z',
#   'https://swapi.dev/api/people/37/'],
#  ['Rugor Nass',
#   '206',
#   'unknown',
#   'none',
#   'green',
#   'orange',
#   'unknown',
#   'male',
#   'https://swapi.dev/api/planets/8/',
#   ['https://swapi.dev/api/films/4/'],
#   ['https://swapi.dev/api/species/12/'],
#   [],
#   [],
#   '2014-12-19T17:33:38.909000Z',
#   '2014-12-20T21:17:50.388000Z',
#   'https://swapi.dev/api/people/38/'],
#  ['Ric Olié',
#   '183',
#   'unknown',
#   'brown',
#   'fair',
#   'blue',
#   'unknown',
#   'male',
#   'https://swapi.dev/api/planets/8/',
#   ['https://swapi.dev/api/films/4/'],
#   [],
#   [],
#   ['https://swapi.dev/api/starships/40/'],
#   '2014-12-19T17:45:01.522000Z',
#   '2014-12-20T21:17:50.392000Z',
#   'https://swapi.dev/api/people/39/'],
#  ['Watto',
#   '137',
#   'unknown',
#   'black',
#   'blue, grey',
#   'yellow',
#   'unknown',
#   'male',
#   'https://swapi.dev/api/planets/34/',
#   ['https://swapi.dev/api/films/4/', 'https://swapi.dev/api/films/5/'],
#   ['https://swapi.dev/api/species/13/'],
#   [],
#   [],
#   '2014-12-19T17:48:54.647000Z',
#   '2014-12-20T21:17:50.395000Z',
#   'https://swapi.dev/api/people/40/'],
#  ['Sebulba',
#   '112',
#   '40',
#   'none',
#   'grey, red',
#   'orange',
#   'unknown',
#   'male',
#   'https://swapi.dev/api/planets/35/',
#   ['https://swapi.dev/api/films/4/'],
#   ['https://swapi.dev/api/species/14/'],
#   [],
#   [],
#   '2014-12-19T17:53:02.586000Z',
#   '2014-12-20T21:17:50.397000Z',
#   'https://swapi.dev/api/people/41/']]

# %%
# Página 4
#Catalogando as cores de pele desta página 4:
# Out:
#   Input In [18]
#     Catalogando as cores de pele desta página 4:
#                 ^
# SyntaxError: invalid syntax

# %%
cor_da_pele = df[['skin_color']]
display(cor_da_pele)
# Out:
#       skin_color
# 0           fair
# 1  mottled green
# 2           fair
# 3          light
# 4         orange
# 5           grey
# 6          green
# 7           fair
# 8     blue, grey
# 9      grey, red

# %%
# Página 4
# Organizando a lista das cores de pele

# %%
listacordapele = cor_da_pele ["skin_color"].tolist()
print(listacordapele)
# Out:
# ['fair', 'mottled green', 'fair', 'light', 'orange', 'grey', 'green', 'fair', 'blue, grey', 'grey, red']

# %%
# Página 4
# Eliminando da lista as cores de pele repetidas:

# %%
cor_da_pele_nao_repetida = {'fair', 'mottled green', 'fair', 'light', 'orange', 'grey', 'green', 'fair', 'blue, grey', 'grey, red'}
print(cor_da_pele_nao_repetida)
# Out:
# {'grey, red', 'blue, grey', 'light', 'green', 'grey', 'mottled green', 'fair', 'orange'}
