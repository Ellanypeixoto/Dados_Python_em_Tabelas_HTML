# %%
import pandas as pd
import numpy as np

# %%
# Página 8 (https://swapi.dev/api/people/?page=8)
# capturando a lista de pessoas, para compor a tabela:

# %%
results_page_8 = [
  
           {
            "name": "Lama Su", 
            "height": "229", 
            "mass": "88", 
            "hair_color": "none", 
            "skin_color": "grey", 
            "eye_color": "black", 
            "birth_year": "unknown", 
            "gender": "male", 
            "homeworld": "https://swapi.dev/api/planets/10/", 
            "films": [
                "https://swapi.dev/api/films/5/"
            ], 
            "species": [
                "https://swapi.dev/api/species/32/"
            ], 
            "vehicles": [], 
            "starships": [], 
            "created": "2014-12-20T17:30:50.416000Z", 
            "edited": "2014-12-20T21:17:50.473000Z", 
            "url": "https://swapi.dev/api/people/72/"
        }, 
        {
            "name": "Taun We", 
            "height": "213", 
            "mass": "unknown", 
            "hair_color": "none", 
            "skin_color": "grey", 
            "eye_color": "black", 
            "birth_year": "unknown", 
            "gender": "female", 
            "homeworld": "https://swapi.dev/api/planets/10/", 
            "films": [
                "https://swapi.dev/api/films/5/"
            ], 
            "species": [
                "https://swapi.dev/api/species/32/"
            ], 
            "vehicles": [], 
            "starships": [], 
            "created": "2014-12-20T17:31:21.195000Z", 
            "edited": "2014-12-20T21:17:50.474000Z", 
            "url": "https://swapi.dev/api/people/73/"
        }, 
        {
            "name": "Jocasta Nu", 
            "height": "167", 
            "mass": "unknown", 
            "hair_color": "white", 
            "skin_color": "fair", 
            "eye_color": "blue", 
            "birth_year": "unknown", 
            "gender": "female", 
            "homeworld": "https://swapi.dev/api/planets/9/", 
            "films": [
                "https://swapi.dev/api/films/5/"
            ], 
            "species": [
                "https://swapi.dev/api/species/1/"
            ], 
            "vehicles": [], 
            "starships": [], 
            "created": "2014-12-20T17:32:51.996000Z", 
            "edited": "2014-12-20T21:17:50.476000Z", 
            "url": "https://swapi.dev/api/people/74/"
        }, 
        {
            "name": "R4-P17", 
            "height": "96", 
            "mass": "unknown", 
            "hair_color": "none", 
            "skin_color": "silver, red", 
            "eye_color": "red, blue", 
            "birth_year": "unknown", 
            "gender": "female", 
            "homeworld": "https://swapi.dev/api/planets/28/", 
            "films": [
                "https://swapi.dev/api/films/5/", 
                "https://swapi.dev/api/films/6/"
            ], 
            "species": [], 
            "vehicles": [], 
            "starships": [], 
            "created": "2014-12-20T17:43:36.409000Z", 
            "edited": "2014-12-20T21:17:50.478000Z", 
            "url": "https://swapi.dev/api/people/75/"
        }, 
        {
            "name": "Wat Tambor", 
            "height": "193", 
            "mass": "48", 
            "hair_color": "none", 
            "skin_color": "green, grey", 
            "eye_color": "unknown", 
            "birth_year": "unknown", 
            "gender": "male", 
            "homeworld": "https://swapi.dev/api/planets/56/", 
            "films": [
                "https://swapi.dev/api/films/5/"
            ], 
            "species": [
                "https://swapi.dev/api/species/33/"
            ], 
            "vehicles": [], 
            "starships": [], 
            "created": "2014-12-20T17:53:52.607000Z", 
            "edited": "2014-12-20T21:17:50.481000Z", 
            "url": "https://swapi.dev/api/people/76/"
        }, 
        {
            "name": "San Hill", 
            "height": "191", 
            "mass": "unknown", 
            "hair_color": "none", 
            "skin_color": "grey", 
            "eye_color": "gold", 
            "birth_year": "unknown", 
            "gender": "male", 
            "homeworld": "https://swapi.dev/api/planets/57/", 
            "films": [
                "https://swapi.dev/api/films/5/"
            ], 
            "species": [
                "https://swapi.dev/api/species/34/"
            ], 
            "vehicles": [], 
            "starships": [], 
            "created": "2014-12-20T17:58:17.049000Z", 
            "edited": "2014-12-20T21:17:50.484000Z", 
            "url": "https://swapi.dev/api/people/77/"
        }, 
        {
            "name": "Shaak Ti", 
            "height": "178", 
            "mass": "57", 
            "hair_color": "none", 
            "skin_color": "red, blue, white", 
            "eye_color": "black", 
            "birth_year": "unknown", 
            "gender": "female", 
            "homeworld": "https://swapi.dev/api/planets/58/", 
            "films": [
                "https://swapi.dev/api/films/5/", 
                "https://swapi.dev/api/films/6/"
            ], 
            "species": [
                "https://swapi.dev/api/species/35/"
            ], 
            "vehicles": [], 
            "starships": [], 
            "created": "2014-12-20T18:44:01.103000Z", 
            "edited": "2014-12-20T21:17:50.486000Z", 
            "url": "https://swapi.dev/api/people/78/"
        }, 
        {
            "name": "Grievous", 
            "height": "216", 
            "mass": "159", 
            "hair_color": "none", 
            "skin_color": "brown, white", 
            "eye_color": "green, yellow", 
            "birth_year": "unknown", 
            "gender": "male", 
            "homeworld": "https://swapi.dev/api/planets/59/", 
            "films": [
                "https://swapi.dev/api/films/6/"
            ], 
            "species": [
                "https://swapi.dev/api/species/36/"
            ], 
            "vehicles": [
                "https://swapi.dev/api/vehicles/60/"
            ], 
            "starships": [
                "https://swapi.dev/api/starships/74/"
            ], 
            "created": "2014-12-20T19:43:53.348000Z", 
            "edited": "2014-12-20T21:17:50.488000Z", 
            "url": "https://swapi.dev/api/people/79/"
        }, 
        {
            "name": "Tarfful", 
            "height": "234", 
            "mass": "136", 
            "hair_color": "brown", 
            "skin_color": "brown", 
            "eye_color": "blue", 
            "birth_year": "unknown", 
            "gender": "male", 
            "homeworld": "https://swapi.dev/api/planets/14/", 
            "films": [
                "https://swapi.dev/api/films/6/"
            ], 
            "species": [
                "https://swapi.dev/api/species/3/"
            ], 
            "vehicles": [], 
            "starships": [], 
            "created": "2014-12-20T19:46:34.209000Z", 
            "edited": "2014-12-20T21:17:50.491000Z", 
            "url": "https://swapi.dev/api/people/80/"
        }, 
        {
            "name": "Raymus Antilles", 
            "height": "188", 
            "mass": "79", 
            "hair_color": "brown", 
            "skin_color": "light", 
            "eye_color": "brown", 
            "birth_year": "unknown", 
            "gender": "male", 
            "homeworld": "https://swapi.dev/api/planets/2/", 
            "films": [
                "https://swapi.dev/api/films/1/", 
                "https://swapi.dev/api/films/6/"
            ], 
            "species": [], 
            "vehicles": [], 
            "starships": [], 
            "created": "2014-12-20T19:49:35.583000Z", 
            "edited": "2014-12-20T21:17:50.493000Z", 
            "url": "https://swapi.dev/api/people/81/"
        }
    ]

# %%
# Página 8
# transformando os dados em dataframe:

# %%
df = pd.DataFrame(results_page_8)

print(df)
# Out:
#               name height     mass hair_color        skin_color  \
# 0          Lama Su    229       88       none              grey
# 1          Taun We    213  unknown       none              grey
# 2       Jocasta Nu    167  unknown      white              fair
# 3           R4-P17     96  unknown       none       silver, red
# 4       Wat Tambor    193       48       none       green, grey
# 5         San Hill    191  unknown       none              grey
# 6         Shaak Ti    178       57       none  red, blue, white
# 7         Grievous    216      159       none      brown, white
# 8          Tarfful    234      136      brown             brown
# 9  Raymus Antilles    188       79      brown             light
#
#        eye_color birth_year  gender                          homeworld  \
# 0          black    unknown    male  https://swapi.dev/api/planets/10/
# 1          black    unknown  female  https://swapi.dev/api/planets/10/
# 2           blue    unknown  female   https://swapi.dev/api/planets/9/
# 3      red, blue    unknown  female  https://swapi.dev/api/planets/28/
# 4        unknown    unknown    male  https://swapi.dev/api/planets/56/
# 5           gold    unknown    male  https://swapi.dev/api/planets/57/
# 6          black    unknown  female  https://swapi.dev/api/planets/58/
# 7  green, yellow    unknown    male  https://swapi.dev/api/planets/59/
# 8           blue    unknown    male  https://swapi.dev/api/planets/14/
# 9          brown    unknown    male   https://swapi.dev/api/planets/2/
#
#                                                films  \
# 0                   [https://swapi.dev/api/films/5/]
# 1                   [https://swapi.dev/api/films/5/]
# 2                   [https://swapi.dev/api/films/5/]
# 3  [https://swapi.dev/api/films/5/, https://swapi...
# 4                   [https://swapi.dev/api/films/5/]
# 5                   [https://swapi.dev/api/films/5/]
# 6  [https://swapi.dev/api/films/5/, https://swapi...
# 7                   [https://swapi.dev/api/films/6/]
# 8                   [https://swapi.dev/api/films/6/]
# 9  [https://swapi.dev/api/films/1/, https://swapi...
#
#                                species                              vehicles  \
# 0  [https://swapi.dev/api/species/32/]                                    []
# 1  [https://swapi.dev/api/species/32/]                                    []
# 2   [https://swapi.dev/api/species/1/]                                    []
# 3                                   []                                    []
# 4  [https://swapi.dev/api/species/33/]                                    []
# 5  [https://swapi.dev/api/species/34/]                                    []
# 6  [https://swapi.dev/api/species/35/]                                    []
# 7  [https://swapi.dev/api/species/36/]  [https://swapi.dev/api/vehicles/60/]
# 8   [https://swapi.dev/api/species/3/]                                    []
# 9                                   []                                    []
#
#                                starships                      created  \
# 0                                     []  2014-12-20T17:30:50.416000Z
# 1                                     []  2014-12-20T17:31:21.195000Z
# 2                                     []  2014-12-20T17:32:51.996000Z
# 3                                     []  2014-12-20T17:43:36.409000Z
# 4                                     []  2014-12-20T17:53:52.607000Z
# 5                                     []  2014-12-20T17:58:17.049000Z
# 6                                     []  2014-12-20T18:44:01.103000Z
# 7  [https://swapi.dev/api/starships/74/]  2014-12-20T19:43:53.348000Z
# 8                                     []  2014-12-20T19:46:34.209000Z
# 9                                     []  2014-12-20T19:49:35.583000Z
#
#                         edited                               url
# 0  2014-12-20T21:17:50.473000Z  https://swapi.dev/api/people/72/
# 1  2014-12-20T21:17:50.474000Z  https://swapi.dev/api/people/73/
# 2  2014-12-20T21:17:50.476000Z  https://swapi.dev/api/people/74/
# 3  2014-12-20T21:17:50.478000Z  https://swapi.dev/api/people/75/
# 4  2014-12-20T21:17:50.481000Z  https://swapi.dev/api/people/76/
# 5  2014-12-20T21:17:50.484000Z  https://swapi.dev/api/people/77/
# 6  2014-12-20T21:17:50.486000Z  https://swapi.dev/api/people/78/
# 7  2014-12-20T21:17:50.488000Z  https://swapi.dev/api/people/79/
# 8  2014-12-20T21:17:50.491000Z  https://swapi.dev/api/people/80/
# 9  2014-12-20T21:17:50.493000Z  https://swapi.dev/api/people/81/

# %%
# Página 8
# transformando o dataframe em tabela

# %%
df
# Out:
#               name height     mass hair_color        skin_color  \
# 0          Lama Su    229       88       none              grey
# 1          Taun We    213  unknown       none              grey
# 2       Jocasta Nu    167  unknown      white              fair
# 3           R4-P17     96  unknown       none       silver, red
# 4       Wat Tambor    193       48       none       green, grey
# 5         San Hill    191  unknown       none              grey
# 6         Shaak Ti    178       57       none  red, blue, white
# 7         Grievous    216      159       none      brown, white
# 8          Tarfful    234      136      brown             brown
# 9  Raymus Antilles    188       79      brown             light
#
#        eye_color birth_year  gender                          homeworld  \
# 0          black    unknown    male  https://swapi.dev/api/planets/10/
# 1          black    unknown  female  https://swapi.dev/api/planets/10/
# 2           blue    unknown  female   https://swapi.dev/api/planets/9/
# 3      red, blue    unknown  female  https://swapi.dev/api/planets/28/
# 4        unknown    unknown    male  https://swapi.dev/api/planets/56/
# 5           gold    unknown    male  https://swapi.dev/api/planets/57/
# 6          black    unknown  female  https://swapi.dev/api/planets/58/
# 7  green, yellow    unknown    male  https://swapi.dev/api/planets/59/
# 8           blue    unknown    male  https://swapi.dev/api/planets/14/
# 9          brown    unknown    male   https://swapi.dev/api/planets/2/
#
#                                                films  \
# 0                   [https://swapi.dev/api/films/5/]
# 1                   [https://swapi.dev/api/films/5/]
# 2                   [https://swapi.dev/api/films/5/]
# 3  [https://swapi.dev/api/films/5/, https://swapi...
# 4                   [https://swapi.dev/api/films/5/]
# 5                   [https://swapi.dev/api/films/5/]
# 6  [https://swapi.dev/api/films/5/, https://swapi...
# 7                   [https://swapi.dev/api/films/6/]
# 8                   [https://swapi.dev/api/films/6/]
# 9  [https://swapi.dev/api/films/1/, https://swapi...
#
#                                species                              vehicles  \
# 0  [https://swapi.dev/api/species/32/]                                    []
# 1  [https://swapi.dev/api/species/32/]                                    []
# 2   [https://swapi.dev/api/species/1/]                                    []
# 3                                   []                                    []
# 4  [https://swapi.dev/api/species/33/]                                    []
# 5  [https://swapi.dev/api/species/34/]                                    []
# 6  [https://swapi.dev/api/species/35/]                                    []
# 7  [https://swapi.dev/api/species/36/]  [https://swapi.dev/api/vehicles/60/]
# 8   [https://swapi.dev/api/species/3/]                                    []
# 9                                   []                                    []
#
#                                starships                      created  \
# 0                                     []  2014-12-20T17:30:50.416000Z
# 1                                     []  2014-12-20T17:31:21.195000Z
# 2                                     []  2014-12-20T17:32:51.996000Z
# 3                                     []  2014-12-20T17:43:36.409000Z
# 4                                     []  2014-12-20T17:53:52.607000Z
# 5                                     []  2014-12-20T17:58:17.049000Z
# 6                                     []  2014-12-20T18:44:01.103000Z
# 7  [https://swapi.dev/api/starships/74/]  2014-12-20T19:43:53.348000Z
# 8                                     []  2014-12-20T19:46:34.209000Z
# 9                                     []  2014-12-20T19:49:35.583000Z
#
#                         edited                               url
# 0  2014-12-20T21:17:50.473000Z  https://swapi.dev/api/people/72/
# 1  2014-12-20T21:17:50.474000Z  https://swapi.dev/api/people/73/
# 2  2014-12-20T21:17:50.476000Z  https://swapi.dev/api/people/74/
# 3  2014-12-20T21:17:50.478000Z  https://swapi.dev/api/people/75/
# 4  2014-12-20T21:17:50.481000Z  https://swapi.dev/api/people/76/
# 5  2014-12-20T21:17:50.484000Z  https://swapi.dev/api/people/77/
# 6  2014-12-20T21:17:50.486000Z  https://swapi.dev/api/people/78/
# 7  2014-12-20T21:17:50.488000Z  https://swapi.dev/api/people/79/
# 8  2014-12-20T21:17:50.491000Z  https://swapi.dev/api/people/80/
# 9  2014-12-20T21:17:50.493000Z  https://swapi.dev/api/people/81/

# %%
# Página 8
# selecionando os dados solicitados: nome e cor da pele

# %%
nome_e_cor_da_pele = df[['name', 'skin_color']]
display(nome_e_cor_da_pele)
# Out:
#               name        skin_color
# 0          Lama Su              grey
# 1          Taun We              grey
# 2       Jocasta Nu              fair
# 3           R4-P17       silver, red
# 4       Wat Tambor       green, grey
# 5         San Hill              grey
# 6         Shaak Ti  red, blue, white
# 7         Grievous      brown, white
# 8          Tarfful             brown
# 9  Raymus Antilles             light

# %%
# Página 8
# Colunas com as propriedades e seus respectivos valores, de acordo com o retorno da api nome , altura, peso, aniversário e gênero.

# %%
nome_altura_peso_aniversario_genero = df[['name', 'height', 'mass', 'birth_year', 'gender' ]]
display(nome_altura_peso_aniversario_genero)
# Out:
#               name height     mass birth_year  gender
# 0          Lama Su    229       88    unknown    male
# 1          Taun We    213  unknown    unknown  female
# 2       Jocasta Nu    167  unknown    unknown  female
# 3           R4-P17     96  unknown    unknown  female
# 4       Wat Tambor    193       48    unknown    male
# 5         San Hill    191  unknown    unknown    male
# 6         Shaak Ti    178       57    unknown  female
# 7         Grievous    216      159    unknown    male
# 8          Tarfful    234      136    unknown    male
# 9  Raymus Antilles    188       79    unknown    male

# %%
# transformando a tabela python completa em uma tabela HTML (para construir as páginas)

# %%
html=df.to_html()
print(html)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>height</th>
#       <th>mass</th>
#       <th>hair_color</th>
#       <th>skin_color</th>
#       <th>eye_color</th>
#       <th>birth_year</th>
#       <th>gender</th>
#       <th>homeworld</th>
#       <th>films</th>
#       <th>species</th>
#       <th>vehicles</th>
#       <th>starships</th>
#       <th>created</th>
#       <th>edited</th>
#       <th>url</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Lama Su</td>
#       <td>229</td>
#       <td>88</td>
#       <td>none</td>
#       <td>grey</td>
#       <td>black</td>
#       <td>unknown</td>
#       <td>male</td>
#       <td>https://swapi.dev/api/planets/10/</td>
#       <td>[https://swapi.dev/api/films/5/]</td>
#       <td>[https://swapi.dev/api/species/32/]</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>2014-12-20T17:30:50.416000Z</td>
#       <td>2014-12-20T21:17:50.473000Z</td>
#       <td>https://swapi.dev/api/people/72/</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Taun We</td>
#       <td>213</td>
#       <td>unknown</td>
#       <td>none</td>
#       <td>grey</td>
#       <td>black</td>
#       <td>unknown</td>
#       <td>female</td>
#       <td>https://swapi.dev/api/planets/10/</td>
#       <td>[https://swapi.dev/api/films/5/]</td>
#       <td>[https://swapi.dev/api/species/32/]</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>2014-12-20T17:31:21.195000Z</td>
#       <td>2014-12-20T21:17:50.474000Z</td>
#       <td>https://swapi.dev/api/people/73/</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Jocasta Nu</td>
#       <td>167</td>
#       <td>unknown</td>
#       <td>white</td>
#       <td>fair</td>
#       <td>blue</td>
#       <td>unknown</td>
#       <td>female</td>
#       <td>https://swapi.dev/api/planets/9/</td>
#       <td>[https://swapi.dev/api/films/5/]</td>
#       <td>[https://swapi.dev/api/species/1/]</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>2014-12-20T17:32:51.996000Z</td>
#       <td>2014-12-20T21:17:50.476000Z</td>
#       <td>https://swapi.dev/api/people/74/</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>R4-P17</td>
#       <td>96</td>
#       <td>unknown</td>
#       <td>none</td>
#       <td>silver, red</td>
#       <td>red, blue</td>
#       <td>unknown</td>
#       <td>female</td>
#       <td>https://swapi.dev/api/planets/28/</td>
#       <td>[https://swapi.dev/api/films/5/, https://swapi.dev/api/films/6/]</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>2014-12-20T17:43:36.409000Z</td>
#       <td>2014-12-20T21:17:50.478000Z</td>
#       <td>https://swapi.dev/api/people/75/</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Wat Tambor</td>
#       <td>193</td>
#       <td>48</td>
#       <td>none</td>
#       <td>green, grey</td>
#       <td>unknown</td>
#       <td>unknown</td>
#       <td>male</td>
#       <td>https://swapi.dev/api/planets/56/</td>
#       <td>[https://swapi.dev/api/films/5/]</td>
#       <td>[https://swapi.dev/api/species/33/]</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>2014-12-20T17:53:52.607000Z</td>
#       <td>2014-12-20T21:17:50.481000Z</td>
#       <td>https://swapi.dev/api/people/76/</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>San Hill</td>
#       <td>191</td>
#       <td>unknown</td>
#       <td>none</td>
#       <td>grey</td>
#       <td>gold</td>
#       <td>unknown</td>
#       <td>male</td>
#       <td>https://swapi.dev/api/planets/57/</td>
#       <td>[https://swapi.dev/api/films/5/]</td>
#       <td>[https://swapi.dev/api/species/34/]</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>2014-12-20T17:58:17.049000Z</td>
#       <td>2014-12-20T21:17:50.484000Z</td>
#       <td>https://swapi.dev/api/people/77/</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Shaak Ti</td>
#       <td>178</td>
#       <td>57</td>
#       <td>none</td>
#       <td>red, blue, white</td>
#       <td>black</td>
#       <td>unknown</td>
#       <td>female</td>
#       <td>https://swapi.dev/api/planets/58/</td>
#       <td>[https://swapi.dev/api/films/5/, https://swapi.dev/api/films/6/]</td>
#       <td>[https://swapi.dev/api/species/35/]</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>2014-12-20T18:44:01.103000Z</td>
#       <td>2014-12-20T21:17:50.486000Z</td>
#       <td>https://swapi.dev/api/people/78/</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Grievous</td>
#       <td>216</td>
#       <td>159</td>
#       <td>none</td>
#       <td>brown, white</td>
#       <td>green, yellow</td>
#       <td>unknown</td>
#       <td>male</td>
#       <td>https://swapi.dev/api/planets/59/</td>
#       <td>[https://swapi.dev/api/films/6/]</td>
#       <td>[https://swapi.dev/api/species/36/]</td>
#       <td>[https://swapi.dev/api/vehicles/60/]</td>
#       <td>[https://swapi.dev/api/starships/74/]</td>
#       <td>2014-12-20T19:43:53.348000Z</td>
#       <td>2014-12-20T21:17:50.488000Z</td>
#       <td>https://swapi.dev/api/people/79/</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Tarfful</td>
#       <td>234</td>
#       <td>136</td>
#       <td>brown</td>
#       <td>brown</td>
#       <td>blue</td>
#       <td>unknown</td>
#       <td>male</td>
#       <td>https://swapi.dev/api/planets/14/</td>
#       <td>[https://swapi.dev/api/films/6/]</td>
#       <td>[https://swapi.dev/api/species/3/]</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>2014-12-20T19:46:34.209000Z</td>
#       <td>2014-12-20T21:17:50.491000Z</td>
#       <td>https://swapi.dev/api/people/80/</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Raymus Antilles</td>
#       <td>188</td>
#       <td>79</td>
#       <td>brown</td>
#       <td>light</td>
#       <td>brown</td>
#       <td>unknown</td>
#       <td>male</td>
#       <td>https://swapi.dev/api/planets/2/</td>
#       <td>[https://swapi.dev/api/films/1/, https://swapi.dev/api/films/6/]</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>2014-12-20T19:49:35.583000Z</td>
#       <td>2014-12-20T21:17:50.493000Z</td>
#       <td>https://swapi.dev/api/people/81/</td>
#     </tr>
#   </tbody>
# </table>

# %%
#exportando a tabela escrita em html para arquivo html:

# %%
arq = open("tabela_pagina_8.html", "w")
arq = arq.write(html)

# %%
#organizando os dados de cada pessoa

# %%
df.values.tolist()
# Out:
# [['Lama Su',
#   '229',
#   '88',
#   'none',
#   'grey',
#   'black',
#   'unknown',
#   'male',
#   'https://swapi.dev/api/planets/10/',
#   ['https://swapi.dev/api/films/5/'],
#   ['https://swapi.dev/api/species/32/'],
#   [],
#   [],
#   '2014-12-20T17:30:50.416000Z',
#   '2014-12-20T21:17:50.473000Z',
#   'https://swapi.dev/api/people/72/'],
#  ['Taun We',
#   '213',
#   'unknown',
#   'none',
#   'grey',
#   'black',
#   'unknown',
#   'female',
#   'https://swapi.dev/api/planets/10/',
#   ['https://swapi.dev/api/films/5/'],
#   ['https://swapi.dev/api/species/32/'],
#   [],
#   [],
#   '2014-12-20T17:31:21.195000Z',
#   '2014-12-20T21:17:50.474000Z',
#   'https://swapi.dev/api/people/73/'],
#  ['Jocasta Nu',
#   '167',
#   'unknown',
#   'white',
#   'fair',
#   'blue',
#   'unknown',
#   'female',
#   'https://swapi.dev/api/planets/9/',
#   ['https://swapi.dev/api/films/5/'],
#   ['https://swapi.dev/api/species/1/'],
#   [],
#   [],
#   '2014-12-20T17:32:51.996000Z',
#   '2014-12-20T21:17:50.476000Z',
#   'https://swapi.dev/api/people/74/'],
#  ['R4-P17',
#   '96',
#   'unknown',
#   'none',
#   'silver, red',
#   'red, blue',
#   'unknown',
#   'female',
#   'https://swapi.dev/api/planets/28/',
#   ['https://swapi.dev/api/films/5/', 'https://swapi.dev/api/films/6/'],
#   [],
#   [],
#   [],
#   '2014-12-20T17:43:36.409000Z',
#   '2014-12-20T21:17:50.478000Z',
#   'https://swapi.dev/api/people/75/'],
#  ['Wat Tambor',
#   '193',
#   '48',
#   'none',
#   'green, grey',
#   'unknown',
#   'unknown',
#   'male',
#   'https://swapi.dev/api/planets/56/',
#   ['https://swapi.dev/api/films/5/'],
#   ['https://swapi.dev/api/species/33/'],
#   [],
#   [],
#   '2014-12-20T17:53:52.607000Z',
#   '2014-12-20T21:17:50.481000Z',
#   'https://swapi.dev/api/people/76/'],
#  ['San Hill',
#   '191',
#   'unknown',
#   'none',
#   'grey',
#   'gold',
#   'unknown',
#   'male',
#   'https://swapi.dev/api/planets/57/',
#   ['https://swapi.dev/api/films/5/'],
#   ['https://swapi.dev/api/species/34/'],
#   [],
#   [],
#   '2014-12-20T17:58:17.049000Z',
#   '2014-12-20T21:17:50.484000Z',
#   'https://swapi.dev/api/people/77/'],
#  ['Shaak Ti',
#   '178',
#   '57',
#   'none',
#   'red, blue, white',
#   'black',
#   'unknown',
#   'female',
#   'https://swapi.dev/api/planets/58/',
#   ['https://swapi.dev/api/films/5/', 'https://swapi.dev/api/films/6/'],
#   ['https://swapi.dev/api/species/35/'],
#   [],
#   [],
#   '2014-12-20T18:44:01.103000Z',
#   '2014-12-20T21:17:50.486000Z',
#   'https://swapi.dev/api/people/78/'],
#  ['Grievous',
#   '216',
#   '159',
#   'none',
#   'brown, white',
#   'green, yellow',
#   'unknown',
#   'male',
#   'https://swapi.dev/api/planets/59/',
#   ['https://swapi.dev/api/films/6/'],
#   ['https://swapi.dev/api/species/36/'],
#   ['https://swapi.dev/api/vehicles/60/'],
#   ['https://swapi.dev/api/starships/74/'],
#   '2014-12-20T19:43:53.348000Z',
#   '2014-12-20T21:17:50.488000Z',
#   'https://swapi.dev/api/people/79/'],
#  ['Tarfful',
#   '234',
#   '136',
#   'brown',
#   'brown',
#   'blue',
#   'unknown',
#   'male',
#   'https://swapi.dev/api/planets/14/',
#   ['https://swapi.dev/api/films/6/'],
#   ['https://swapi.dev/api/species/3/'],
#   [],
#   [],
#   '2014-12-20T19:46:34.209000Z',
#   '2014-12-20T21:17:50.491000Z',
#   'https://swapi.dev/api/people/80/'],
#  ['Raymus Antilles',
#   '188',
#   '79',
#   'brown',
#   'light',
#   'brown',
#   'unknown',
#   'male',
#   'https://swapi.dev/api/planets/2/',
#   ['https://swapi.dev/api/films/1/', 'https://swapi.dev/api/films/6/'],
#   [],
#   [],
#   [],
#   '2014-12-20T19:49:35.583000Z',
#   '2014-12-20T21:17:50.493000Z',
#   'https://swapi.dev/api/people/81/']]

# %%
# Página 8
#Catalogando as cores de pele desta página 8:

# %%
cor_da_pele = df[['skin_color']]
display(cor_da_pele)
# Out:
#          skin_color
# 0              grey
# 1              grey
# 2              fair
# 3       silver, red
# 4       green, grey
# 5              grey
# 6  red, blue, white
# 7      brown, white
# 8             brown
# 9             light

# %%
# Página 8
# Organizando a lista das cores de pele

# %%
listacordapele = cor_da_pele ["skin_color"].tolist()
print(listacordapele)
# Out:
# ['grey', 'grey', 'fair', 'silver, red', 'green, grey', 'grey', 'red, blue, white', 'brown, white', 'brown', 'light']

# %%
# Página 8
# Eliminando da lista as cores de pele repetidas:

# %%
cor_da_pele_nao_repetida = {'grey', 'grey', 'fair', 'silver, red', 'green, grey', 'grey', 'red, blue, white', 'brown, white', 'brown', 'light'}
print(cor_da_pele_nao_repetida)
# Out:
# {'fair', 'brown, white', 'green, grey', 'grey', 'red, blue, white', 'brown', 'silver, red', 'light'}
