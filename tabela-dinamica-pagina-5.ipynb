# %%
import pandas as pd
import numpy as np

# %%
# Página 5 (https://swapi.dev/api/people/?page=5)
# capturando a lista de pessoas, para compor a tabela:

# %%
results_page_5 = [
     
       {
            "name": "Quarsh Panaka", 
            "height": "183", 
            "mass": "unknown", 
            "hair_color": "black", 
            "skin_color": "dark", 
            "eye_color": "brown", 
            "birth_year": "62BBY", 
            "gender": "male", 
            "homeworld": "https://swapi.dev/api/planets/8/", 
            "films": [
                "https://swapi.dev/api/films/4/"
            ], 
            "species": [], 
            "vehicles": [], 
            "starships": [], 
            "created": "2014-12-19T17:55:43.348000Z", 
            "edited": "2014-12-20T21:17:50.399000Z", 
            "url": "https://swapi.dev/api/people/42/"
        }, 
        {
            "name": "Shmi Skywalker", 
            "height": "163", 
            "mass": "unknown", 
            "hair_color": "black", 
            "skin_color": "fair", 
            "eye_color": "brown", 
            "birth_year": "72BBY", 
            "gender": "female", 
            "homeworld": "https://swapi.dev/api/planets/1/", 
            "films": [
                "https://swapi.dev/api/films/4/", 
                "https://swapi.dev/api/films/5/"
            ], 
            "species": [], 
            "vehicles": [], 
            "starships": [], 
            "created": "2014-12-19T17:57:41.191000Z", 
            "edited": "2014-12-20T21:17:50.401000Z", 
            "url": "https://swapi.dev/api/people/43/"
        }, 
        {
            "name": "Darth Maul", 
            "height": "175", 
            "mass": "80", 
            "hair_color": "none", 
            "skin_color": "red", 
            "eye_color": "yellow", 
            "birth_year": "54BBY", 
            "gender": "male", 
            "homeworld": "https://swapi.dev/api/planets/36/", 
            "films": [
                "https://swapi.dev/api/films/4/"
            ], 
            "species": [
                "https://swapi.dev/api/species/22/"
            ], 
            "vehicles": [
                "https://swapi.dev/api/vehicles/42/"
            ], 
            "starships": [
                "https://swapi.dev/api/starships/41/"
            ], 
            "created": "2014-12-19T18:00:41.929000Z", 
            "edited": "2014-12-20T21:17:50.403000Z", 
            "url": "https://swapi.dev/api/people/44/"
        }, 
        {
            "name": "Bib Fortuna", 
            "height": "180", 
            "mass": "unknown", 
            "hair_color": "none", 
            "skin_color": "pale", 
            "eye_color": "pink", 
            "birth_year": "unknown", 
            "gender": "male", 
            "homeworld": "https://swapi.dev/api/planets/37/", 
            "films": [
                "https://swapi.dev/api/films/3/"
            ], 
            "species": [
                "https://swapi.dev/api/species/15/"
            ], 
            "vehicles": [], 
            "starships": [], 
            "created": "2014-12-20T09:47:02.512000Z", 
            "edited": "2014-12-20T21:17:50.407000Z", 
            "url": "https://swapi.dev/api/people/45/"
        }, 
        {
            "name": "Ayla Secura", 
            "height": "178", 
            "mass": "55", 
            "hair_color": "none", 
            "skin_color": "blue", 
            "eye_color": "hazel", 
            "birth_year": "48BBY", 
            "gender": "female", 
            "homeworld": "https://swapi.dev/api/planets/37/", 
            "films": [
                "https://swapi.dev/api/films/4/", 
                "https://swapi.dev/api/films/5/", 
                "https://swapi.dev/api/films/6/"
            ], 
            "species": [
                "https://swapi.dev/api/species/15/"
            ], 
            "vehicles": [], 
            "starships": [], 
            "created": "2014-12-20T09:48:01.172000Z", 
            "edited": "2014-12-20T21:17:50.409000Z", 
            "url": "https://swapi.dev/api/people/46/"
        }, 
        {
            "name": "Ratts Tyerel", 
            "height": "79", 
            "mass": "15", 
            "hair_color": "none", 
            "skin_color": "grey, blue", 
            "eye_color": "unknown", 
            "birth_year": "unknown", 
            "gender": "male", 
            "homeworld": "https://swapi.dev/api/planets/38/", 
            "films": [
                "https://swapi.dev/api/films/4/"
            ], 
            "species": [
                "https://swapi.dev/api/species/16/"
            ], 
            "vehicles": [], 
            "starships": [], 
            "created": "2014-12-20T09:53:15.086000Z", 
            "edited": "2014-12-20T21:17:50.410000Z", 
            "url": "https://swapi.dev/api/people/47/"
        }, 
        {
            "name": "Dud Bolt", 
            "height": "94", 
            "mass": "45", 
            "hair_color": "none", 
            "skin_color": "blue, grey", 
            "eye_color": "yellow", 
            "birth_year": "unknown", 
            "gender": "male", 
            "homeworld": "https://swapi.dev/api/planets/39/", 
            "films": [
                "https://swapi.dev/api/films/4/"
            ], 
            "species": [
                "https://swapi.dev/api/species/17/"
            ], 
            "vehicles": [], 
            "starships": [], 
            "created": "2014-12-20T09:57:31.858000Z", 
            "edited": "2014-12-20T21:17:50.414000Z", 
            "url": "https://swapi.dev/api/people/48/"
        }, 
        {
            "name": "Gasgano", 
            "height": "122", 
            "mass": "unknown", 
            "hair_color": "none", 
            "skin_color": "white, blue", 
            "eye_color": "black", 
            "birth_year": "unknown", 
            "gender": "male", 
            "homeworld": "https://swapi.dev/api/planets/40/", 
            "films": [
                "https://swapi.dev/api/films/4/"
            ], 
            "species": [
                "https://swapi.dev/api/species/18/"
            ], 
            "vehicles": [], 
            "starships": [], 
            "created": "2014-12-20T10:02:12.223000Z", 
            "edited": "2014-12-20T21:17:50.416000Z", 
            "url": "https://swapi.dev/api/people/49/"
        }, 
        {
            "name": "Ben Quadinaros", 
            "height": "163", 
            "mass": "65", 
            "hair_color": "none", 
            "skin_color": "grey, green, yellow", 
            "eye_color": "orange", 
            "birth_year": "unknown", 
            "gender": "male", 
            "homeworld": "https://swapi.dev/api/planets/41/", 
            "films": [
                "https://swapi.dev/api/films/4/"
            ], 
            "species": [
                "https://swapi.dev/api/species/19/"
            ], 
            "vehicles": [], 
            "starships": [], 
            "created": "2014-12-20T10:08:33.777000Z", 
            "edited": "2014-12-20T21:17:50.417000Z", 
            "url": "https://swapi.dev/api/people/50/"
        }, 
        {
            "name": "Mace Windu", 
            "height": "188", 
            "mass": "84", 
            "hair_color": "none", 
            "skin_color": "dark", 
            "eye_color": "brown", 
            "birth_year": "72BBY", 
            "gender": "male", 
            "homeworld": "https://swapi.dev/api/planets/42/", 
            "films": [
                "https://swapi.dev/api/films/4/", 
                "https://swapi.dev/api/films/5/", 
                "https://swapi.dev/api/films/6/"
            ], 
            "species": [], 
            "vehicles": [], 
            "starships": [], 
            "created": "2014-12-20T10:12:30.846000Z", 
            "edited": "2014-12-20T21:17:50.420000Z", 
            "url": "https://swapi.dev/api/people/51/"
        }
    ]

# %%
# Página 5
# transformando os dados em dataframe:

# %%
df = pd.DataFrame(results_page_5)

print(df)
# Out:
#              name height     mass hair_color           skin_color eye_color  \
# 0   Quarsh Panaka    183  unknown      black                 dark     brown
# 1  Shmi Skywalker    163  unknown      black                 fair     brown
# 2      Darth Maul    175       80       none                  red    yellow
# 3     Bib Fortuna    180  unknown       none                 pale      pink
# 4     Ayla Secura    178       55       none                 blue     hazel
# 5    Ratts Tyerel     79       15       none           grey, blue   unknown
# 6        Dud Bolt     94       45       none           blue, grey    yellow
# 7         Gasgano    122  unknown       none          white, blue     black
# 8  Ben Quadinaros    163       65       none  grey, green, yellow    orange
# 9      Mace Windu    188       84       none                 dark     brown
#
#   birth_year  gender                          homeworld  \
# 0      62BBY    male   https://swapi.dev/api/planets/8/
# 1      72BBY  female   https://swapi.dev/api/planets/1/
# 2      54BBY    male  https://swapi.dev/api/planets/36/
# 3    unknown    male  https://swapi.dev/api/planets/37/
# 4      48BBY  female  https://swapi.dev/api/planets/37/
# 5    unknown    male  https://swapi.dev/api/planets/38/
# 6    unknown    male  https://swapi.dev/api/planets/39/
# 7    unknown    male  https://swapi.dev/api/planets/40/
# 8    unknown    male  https://swapi.dev/api/planets/41/
# 9      72BBY    male  https://swapi.dev/api/planets/42/
#
#                                                films  \
# 0                   [https://swapi.dev/api/films/4/]
# 1  [https://swapi.dev/api/films/4/, https://swapi...
# 2                   [https://swapi.dev/api/films/4/]
# 3                   [https://swapi.dev/api/films/3/]
# 4  [https://swapi.dev/api/films/4/, https://swapi...
# 5                   [https://swapi.dev/api/films/4/]
# 6                   [https://swapi.dev/api/films/4/]
# 7                   [https://swapi.dev/api/films/4/]
# 8                   [https://swapi.dev/api/films/4/]
# 9  [https://swapi.dev/api/films/4/, https://swapi...
#
#                                species                              vehicles  \
# 0                                   []                                    []
# 1                                   []                                    []
# 2  [https://swapi.dev/api/species/22/]  [https://swapi.dev/api/vehicles/42/]
# 3  [https://swapi.dev/api/species/15/]                                    []
# 4  [https://swapi.dev/api/species/15/]                                    []
# 5  [https://swapi.dev/api/species/16/]                                    []
# 6  [https://swapi.dev/api/species/17/]                                    []
# 7  [https://swapi.dev/api/species/18/]                                    []
# 8  [https://swapi.dev/api/species/19/]                                    []
# 9                                   []                                    []
#
#                                starships                      created  \
# 0                                     []  2014-12-19T17:55:43.348000Z
# 1                                     []  2014-12-19T17:57:41.191000Z
# 2  [https://swapi.dev/api/starships/41/]  2014-12-19T18:00:41.929000Z
# 3                                     []  2014-12-20T09:47:02.512000Z
# 4                                     []  2014-12-20T09:48:01.172000Z
# 5                                     []  2014-12-20T09:53:15.086000Z
# 6                                     []  2014-12-20T09:57:31.858000Z
# 7                                     []  2014-12-20T10:02:12.223000Z
# 8                                     []  2014-12-20T10:08:33.777000Z
# 9                                     []  2014-12-20T10:12:30.846000Z
#
#                         edited                               url
# 0  2014-12-20T21:17:50.399000Z  https://swapi.dev/api/people/42/
# 1  2014-12-20T21:17:50.401000Z  https://swapi.dev/api/people/43/
# 2  2014-12-20T21:17:50.403000Z  https://swapi.dev/api/people/44/
# 3  2014-12-20T21:17:50.407000Z  https://swapi.dev/api/people/45/
# 4  2014-12-20T21:17:50.409000Z  https://swapi.dev/api/people/46/
# 5  2014-12-20T21:17:50.410000Z  https://swapi.dev/api/people/47/
# 6  2014-12-20T21:17:50.414000Z  https://swapi.dev/api/people/48/
# 7  2014-12-20T21:17:50.416000Z  https://swapi.dev/api/people/49/
# 8  2014-12-20T21:17:50.417000Z  https://swapi.dev/api/people/50/
# 9  2014-12-20T21:17:50.420000Z  https://swapi.dev/api/people/51/

# %%
# Página 5
# transformando o dataframe em tabela

# %%
df
# Out:
#              name height     mass hair_color           skin_color eye_color  \
# 0   Quarsh Panaka    183  unknown      black                 dark     brown
# 1  Shmi Skywalker    163  unknown      black                 fair     brown
# 2      Darth Maul    175       80       none                  red    yellow
# 3     Bib Fortuna    180  unknown       none                 pale      pink
# 4     Ayla Secura    178       55       none                 blue     hazel
# 5    Ratts Tyerel     79       15       none           grey, blue   unknown
# 6        Dud Bolt     94       45       none           blue, grey    yellow
# 7         Gasgano    122  unknown       none          white, blue     black
# 8  Ben Quadinaros    163       65       none  grey, green, yellow    orange
# 9      Mace Windu    188       84       none                 dark     brown
#
#   birth_year  gender                          homeworld  \
# 0      62BBY    male   https://swapi.dev/api/planets/8/
# 1      72BBY  female   https://swapi.dev/api/planets/1/
# 2      54BBY    male  https://swapi.dev/api/planets/36/
# 3    unknown    male  https://swapi.dev/api/planets/37/
# 4      48BBY  female  https://swapi.dev/api/planets/37/
# 5    unknown    male  https://swapi.dev/api/planets/38/
# 6    unknown    male  https://swapi.dev/api/planets/39/
# 7    unknown    male  https://swapi.dev/api/planets/40/
# 8    unknown    male  https://swapi.dev/api/planets/41/
# 9      72BBY    male  https://swapi.dev/api/planets/42/
#
#                                                films  \
# 0                   [https://swapi.dev/api/films/4/]
# 1  [https://swapi.dev/api/films/4/, https://swapi...
# 2                   [https://swapi.dev/api/films/4/]
# 3                   [https://swapi.dev/api/films/3/]
# 4  [https://swapi.dev/api/films/4/, https://swapi...
# 5                   [https://swapi.dev/api/films/4/]
# 6                   [https://swapi.dev/api/films/4/]
# 7                   [https://swapi.dev/api/films/4/]
# 8                   [https://swapi.dev/api/films/4/]
# 9  [https://swapi.dev/api/films/4/, https://swapi...
#
#                                species                              vehicles  \
# 0                                   []                                    []
# 1                                   []                                    []
# 2  [https://swapi.dev/api/species/22/]  [https://swapi.dev/api/vehicles/42/]
# 3  [https://swapi.dev/api/species/15/]                                    []
# 4  [https://swapi.dev/api/species/15/]                                    []
# 5  [https://swapi.dev/api/species/16/]                                    []
# 6  [https://swapi.dev/api/species/17/]                                    []
# 7  [https://swapi.dev/api/species/18/]                                    []
# 8  [https://swapi.dev/api/species/19/]                                    []
# 9                                   []                                    []
#
#                                starships                      created  \
# 0                                     []  2014-12-19T17:55:43.348000Z
# 1                                     []  2014-12-19T17:57:41.191000Z
# 2  [https://swapi.dev/api/starships/41/]  2014-12-19T18:00:41.929000Z
# 3                                     []  2014-12-20T09:47:02.512000Z
# 4                                     []  2014-12-20T09:48:01.172000Z
# 5                                     []  2014-12-20T09:53:15.086000Z
# 6                                     []  2014-12-20T09:57:31.858000Z
# 7                                     []  2014-12-20T10:02:12.223000Z
# 8                                     []  2014-12-20T10:08:33.777000Z
# 9                                     []  2014-12-20T10:12:30.846000Z
#
#                         edited                               url
# 0  2014-12-20T21:17:50.399000Z  https://swapi.dev/api/people/42/
# 1  2014-12-20T21:17:50.401000Z  https://swapi.dev/api/people/43/
# 2  2014-12-20T21:17:50.403000Z  https://swapi.dev/api/people/44/
# 3  2014-12-20T21:17:50.407000Z  https://swapi.dev/api/people/45/
# 4  2014-12-20T21:17:50.409000Z  https://swapi.dev/api/people/46/
# 5  2014-12-20T21:17:50.410000Z  https://swapi.dev/api/people/47/
# 6  2014-12-20T21:17:50.414000Z  https://swapi.dev/api/people/48/
# 7  2014-12-20T21:17:50.416000Z  https://swapi.dev/api/people/49/
# 8  2014-12-20T21:17:50.417000Z  https://swapi.dev/api/people/50/
# 9  2014-12-20T21:17:50.420000Z  https://swapi.dev/api/people/51/

# %%
# Página 5
# selecionando os dados solicitados: nome e cor da pele

# %%
nome_e_cor_da_pele = df[['name', 'skin_color']]
display(nome_e_cor_da_pele)
# Out:
#              name           skin_color
# 0   Quarsh Panaka                 dark
# 1  Shmi Skywalker                 fair
# 2      Darth Maul                  red
# 3     Bib Fortuna                 pale
# 4     Ayla Secura                 blue
# 5    Ratts Tyerel           grey, blue
# 6        Dud Bolt           blue, grey
# 7         Gasgano          white, blue
# 8  Ben Quadinaros  grey, green, yellow
# 9      Mace Windu                 dark

# %%
# Página 5
# Colunas com as propriedades e seus respectivos valores, de acordo com o retorno da api nome , altura, peso, aniversário e gênero.

# %%
nome_altura_peso_aniversario_genero = df[['name', 'height', 'mass', 'birth_year', 'gender' ]]
display(nome_altura_peso_aniversario_genero)
# Out:
#              name height     mass birth_year  gender
# 0   Quarsh Panaka    183  unknown      62BBY    male
# 1  Shmi Skywalker    163  unknown      72BBY  female
# 2      Darth Maul    175       80      54BBY    male
# 3     Bib Fortuna    180  unknown    unknown    male
# 4     Ayla Secura    178       55      48BBY  female
# 5    Ratts Tyerel     79       15    unknown    male
# 6        Dud Bolt     94       45    unknown    male
# 7         Gasgano    122  unknown    unknown    male
# 8  Ben Quadinaros    163       65    unknown    male
# 9      Mace Windu    188       84      72BBY    male

# %%
# transformando a tabela python completa em uma tabela HTML ( para construir as páginas)

# %%
html=df.to_html()
print(html)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>height</th>
#       <th>mass</th>
#       <th>hair_color</th>
#       <th>skin_color</th>
#       <th>eye_color</th>
#       <th>birth_year</th>
#       <th>gender</th>
#       <th>homeworld</th>
#       <th>films</th>
#       <th>species</th>
#       <th>vehicles</th>
#       <th>starships</th>
#       <th>created</th>
#       <th>edited</th>
#       <th>url</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Quarsh Panaka</td>
#       <td>183</td>
#       <td>unknown</td>
#       <td>black</td>
#       <td>dark</td>
#       <td>brown</td>
#       <td>62BBY</td>
#       <td>male</td>
#       <td>https://swapi.dev/api/planets/8/</td>
#       <td>[https://swapi.dev/api/films/4/]</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>2014-12-19T17:55:43.348000Z</td>
#       <td>2014-12-20T21:17:50.399000Z</td>
#       <td>https://swapi.dev/api/people/42/</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Shmi Skywalker</td>
#       <td>163</td>
#       <td>unknown</td>
#       <td>black</td>
#       <td>fair</td>
#       <td>brown</td>
#       <td>72BBY</td>
#       <td>female</td>
#       <td>https://swapi.dev/api/planets/1/</td>
#       <td>[https://swapi.dev/api/films/4/, https://swapi.dev/api/films/5/]</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>2014-12-19T17:57:41.191000Z</td>
#       <td>2014-12-20T21:17:50.401000Z</td>
#       <td>https://swapi.dev/api/people/43/</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Darth Maul</td>
#       <td>175</td>
#       <td>80</td>
#       <td>none</td>
#       <td>red</td>
#       <td>yellow</td>
#       <td>54BBY</td>
#       <td>male</td>
#       <td>https://swapi.dev/api/planets/36/</td>
#       <td>[https://swapi.dev/api/films/4/]</td>
#       <td>[https://swapi.dev/api/species/22/]</td>
#       <td>[https://swapi.dev/api/vehicles/42/]</td>
#       <td>[https://swapi.dev/api/starships/41/]</td>
#       <td>2014-12-19T18:00:41.929000Z</td>
#       <td>2014-12-20T21:17:50.403000Z</td>
#       <td>https://swapi.dev/api/people/44/</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Bib Fortuna</td>
#       <td>180</td>
#       <td>unknown</td>
#       <td>none</td>
#       <td>pale</td>
#       <td>pink</td>
#       <td>unknown</td>
#       <td>male</td>
#       <td>https://swapi.dev/api/planets/37/</td>
#       <td>[https://swapi.dev/api/films/3/]</td>
#       <td>[https://swapi.dev/api/species/15/]</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>2014-12-20T09:47:02.512000Z</td>
#       <td>2014-12-20T21:17:50.407000Z</td>
#       <td>https://swapi.dev/api/people/45/</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Ayla Secura</td>
#       <td>178</td>
#       <td>55</td>
#       <td>none</td>
#       <td>blue</td>
#       <td>hazel</td>
#       <td>48BBY</td>
#       <td>female</td>
#       <td>https://swapi.dev/api/planets/37/</td>
#       <td>[https://swapi.dev/api/films/4/, https://swapi.dev/api/films/5/, https://swapi.dev/api/films/6/]</td>
#       <td>[https://swapi.dev/api/species/15/]</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>2014-12-20T09:48:01.172000Z</td>
#       <td>2014-12-20T21:17:50.409000Z</td>
#       <td>https://swapi.dev/api/people/46/</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Ratts Tyerel</td>
#       <td>79</td>
#       <td>15</td>
#       <td>none</td>
#       <td>grey, blue</td>
#       <td>unknown</td>
#       <td>unknown</td>
#       <td>male</td>
#       <td>https://swapi.dev/api/planets/38/</td>
#       <td>[https://swapi.dev/api/films/4/]</td>
#       <td>[https://swapi.dev/api/species/16/]</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>2014-12-20T09:53:15.086000Z</td>
#       <td>2014-12-20T21:17:50.410000Z</td>
#       <td>https://swapi.dev/api/people/47/</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Dud Bolt</td>
#       <td>94</td>
#       <td>45</td>
#       <td>none</td>
#       <td>blue, grey</td>
#       <td>yellow</td>
#       <td>unknown</td>
#       <td>male</td>
#       <td>https://swapi.dev/api/planets/39/</td>
#       <td>[https://swapi.dev/api/films/4/]</td>
#       <td>[https://swapi.dev/api/species/17/]</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>2014-12-20T09:57:31.858000Z</td>
#       <td>2014-12-20T21:17:50.414000Z</td>
#       <td>https://swapi.dev/api/people/48/</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Gasgano</td>
#       <td>122</td>
#       <td>unknown</td>
#       <td>none</td>
#       <td>white, blue</td>
#       <td>black</td>
#       <td>unknown</td>
#       <td>male</td>
#       <td>https://swapi.dev/api/planets/40/</td>
#       <td>[https://swapi.dev/api/films/4/]</td>
#       <td>[https://swapi.dev/api/species/18/]</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>2014-12-20T10:02:12.223000Z</td>
#       <td>2014-12-20T21:17:50.416000Z</td>
#       <td>https://swapi.dev/api/people/49/</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Ben Quadinaros</td>
#       <td>163</td>
#       <td>65</td>
#       <td>none</td>
#       <td>grey, green, yellow</td>
#       <td>orange</td>
#       <td>unknown</td>
#       <td>male</td>
#       <td>https://swapi.dev/api/planets/41/</td>
#       <td>[https://swapi.dev/api/films/4/]</td>
#       <td>[https://swapi.dev/api/species/19/]</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>2014-12-20T10:08:33.777000Z</td>
#       <td>2014-12-20T21:17:50.417000Z</td>
#       <td>https://swapi.dev/api/people/50/</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Mace Windu</td>
#       <td>188</td>
#       <td>84</td>
#       <td>none</td>
#       <td>dark</td>
#       <td>brown</td>
#       <td>72BBY</td>
#       <td>male</td>
#       <td>https://swapi.dev/api/planets/42/</td>
#       <td>[https://swapi.dev/api/films/4/, https://swapi.dev/api/films/5/, https://swapi.dev/api/films/6/]</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>2014-12-20T10:12:30.846000Z</td>
#       <td>2014-12-20T21:17:50.420000Z</td>
#       <td>https://swapi.dev/api/people/51/</td>
#     </tr>
#   </tbody>
# </table>

# %%
#exportando a tabela escrita em html para arquivo html:

# %%
arq = open("tabela_pagina_5.html", "w")
arq = arq.write(html)

# %%
#organizando os dados de cada pessoa

# %%
df.values.tolist()
# Out:
# [['Quarsh Panaka',
#   '183',
#   'unknown',
#   'black',
#   'dark',
#   'brown',
#   '62BBY',
#   'male',
#   'https://swapi.dev/api/planets/8/',
#   ['https://swapi.dev/api/films/4/'],
#   [],
#   [],
#   [],
#   '2014-12-19T17:55:43.348000Z',
#   '2014-12-20T21:17:50.399000Z',
#   'https://swapi.dev/api/people/42/'],
#  ['Shmi Skywalker',
#   '163',
#   'unknown',
#   'black',
#   'fair',
#   'brown',
#   '72BBY',
#   'female',
#   'https://swapi.dev/api/planets/1/',
#   ['https://swapi.dev/api/films/4/', 'https://swapi.dev/api/films/5/'],
#   [],
#   [],
#   [],
#   '2014-12-19T17:57:41.191000Z',
#   '2014-12-20T21:17:50.401000Z',
#   'https://swapi.dev/api/people/43/'],
#  ['Darth Maul',
#   '175',
#   '80',
#   'none',
#   'red',
#   'yellow',
#   '54BBY',
#   'male',
#   'https://swapi.dev/api/planets/36/',
#   ['https://swapi.dev/api/films/4/'],
#   ['https://swapi.dev/api/species/22/'],
#   ['https://swapi.dev/api/vehicles/42/'],
#   ['https://swapi.dev/api/starships/41/'],
#   '2014-12-19T18:00:41.929000Z',
#   '2014-12-20T21:17:50.403000Z',
#   'https://swapi.dev/api/people/44/'],
#  ['Bib Fortuna',
#   '180',
#   'unknown',
#   'none',
#   'pale',
#   'pink',
#   'unknown',
#   'male',
#   'https://swapi.dev/api/planets/37/',
#   ['https://swapi.dev/api/films/3/'],
#   ['https://swapi.dev/api/species/15/'],
#   [],
#   [],
#   '2014-12-20T09:47:02.512000Z',
#   '2014-12-20T21:17:50.407000Z',
#   'https://swapi.dev/api/people/45/'],
#  ['Ayla Secura',
#   '178',
#   '55',
#   'none',
#   'blue',
#   'hazel',
#   '48BBY',
#   'female',
#   'https://swapi.dev/api/planets/37/',
#   ['https://swapi.dev/api/films/4/',
#    'https://swapi.dev/api/films/5/',
#    'https://swapi.dev/api/films/6/'],
#   ['https://swapi.dev/api/species/15/'],
#   [],
#   [],
#   '2014-12-20T09:48:01.172000Z',
#   '2014-12-20T21:17:50.409000Z',
#   'https://swapi.dev/api/people/46/'],
#  ['Ratts Tyerel',
#   '79',
#   '15',
#   'none',
#   'grey, blue',
#   'unknown',
#   'unknown',
#   'male',
#   'https://swapi.dev/api/planets/38/',
#   ['https://swapi.dev/api/films/4/'],
#   ['https://swapi.dev/api/species/16/'],
#   [],
#   [],
#   '2014-12-20T09:53:15.086000Z',
#   '2014-12-20T21:17:50.410000Z',
#   'https://swapi.dev/api/people/47/'],
#  ['Dud Bolt',
#   '94',
#   '45',
#   'none',
#   'blue, grey',
#   'yellow',
#   'unknown',
#   'male',
#   'https://swapi.dev/api/planets/39/',
#   ['https://swapi.dev/api/films/4/'],
#   ['https://swapi.dev/api/species/17/'],
#   [],
#   [],
#   '2014-12-20T09:57:31.858000Z',
#   '2014-12-20T21:17:50.414000Z',
#   'https://swapi.dev/api/people/48/'],
#  ['Gasgano',
#   '122',
#   'unknown',
#   'none',
#   'white, blue',
#   'black',
#   'unknown',
#   'male',
#   'https://swapi.dev/api/planets/40/',
#   ['https://swapi.dev/api/films/4/'],
#   ['https://swapi.dev/api/species/18/'],
#   [],
#   [],
#   '2014-12-20T10:02:12.223000Z',
#   '2014-12-20T21:17:50.416000Z',
#   'https://swapi.dev/api/people/49/'],
#  ['Ben Quadinaros',
#   '163',
#   '65',
#   'none',
#   'grey, green, yellow',
#   'orange',
#   'unknown',
#   'male',
#   'https://swapi.dev/api/planets/41/',
#   ['https://swapi.dev/api/films/4/'],
#   ['https://swapi.dev/api/species/19/'],
#   [],
#   [],
#   '2014-12-20T10:08:33.777000Z',
#   '2014-12-20T21:17:50.417000Z',
#   'https://swapi.dev/api/people/50/'],
#  ['Mace Windu',
#   '188',
#   '84',
#   'none',
#   'dark',
#   'brown',
#   '72BBY',
#   'male',
#   'https://swapi.dev/api/planets/42/',
#   ['https://swapi.dev/api/films/4/',
#    'https://swapi.dev/api/films/5/',
#    'https://swapi.dev/api/films/6/'],
#   [],
#   [],
#   [],
#   '2014-12-20T10:12:30.846000Z',
#   '2014-12-20T21:17:50.420000Z',
#   'https://swapi.dev/api/people/51/']]

# %%
# Página 5
#Catalogando as cores de pele desta página 5:

# %%
cor_da_pele = df[['skin_color']]
display(cor_da_pele)
# Out:
#             skin_color
# 0                 dark
# 1                 fair
# 2                  red
# 3                 pale
# 4                 blue
# 5           grey, blue
# 6           blue, grey
# 7          white, blue
# 8  grey, green, yellow
# 9                 dark

# %%
# Página 4
# Organizando a lista das cores de pele

# %%
listacordapele = cor_da_pele ["skin_color"].tolist()
print(listacordapele)
# Out:
# ['dark', 'fair', 'red', 'pale', 'blue', 'grey, blue', 'blue, grey', 'white, blue', 'grey, green, yellow', 'dark']

# %%
# Página 4
# Eliminando da lista as cores de pele repetidas:

# %%
cor_da_pele_nao_repetida = {'dark', 'fair', 'red', 'pale', 'blue', 'grey, blue', 'blue, grey', 'white, blue', 'grey, green, yellow', 'dark'}
print(cor_da_pele_nao_repetida)
# Out:
# {'grey, blue', 'blue, grey', 'dark', 'fair', 'grey, green, yellow', 'pale', 'red', 'white, blue', 'blue'}
