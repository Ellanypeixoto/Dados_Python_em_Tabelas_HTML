# %%
import pandas as pd
import numpy as np

# %%
# Página 2 (https://swapi.dev/api/people/?page=2)
# capturando a lista de pessoas, para compor a tabela:

# %%
results_page_2 = [
        {
            "name": "Anakin Skywalker", 
            "height": "188", 
            "mass": "84", 
            "hair_color": "blond", 
            "skin_color": "fair", 
            "eye_color": "blue", 
            "birth_year": "41.9BBY", 
            "gender": "male", 
            "homeworld": "https://swapi.dev/api/planets/1/", 
            "films": [
                "https://swapi.dev/api/films/4/", 
                "https://swapi.dev/api/films/5/", 
                "https://swapi.dev/api/films/6/"
            ], 
            "species": [], 
            "vehicles": [
                "https://swapi.dev/api/vehicles/44/", 
                "https://swapi.dev/api/vehicles/46/"
            ], 
            "starships": [
                "https://swapi.dev/api/starships/39/", 
                "https://swapi.dev/api/starships/59/", 
                "https://swapi.dev/api/starships/65/"
            ], 
            "created": "2014-12-10T16:20:44.310000Z", 
            "edited": "2014-12-20T21:17:50.327000Z", 
            "url": "https://swapi.dev/api/people/11/"
        }, 
        {
            "name": "Wilhuff Tarkin", 
            "height": "180", 
            "mass": "unknown", 
            "hair_color": "auburn, grey", 
            "skin_color": "fair", 
            "eye_color": "blue", 
            "birth_year": "64BBY", 
            "gender": "male", 
            "homeworld": "https://swapi.dev/api/planets/21/", 
            "films": [
                "https://swapi.dev/api/films/1/", 
                "https://swapi.dev/api/films/6/"
            ], 
            "species": [], 
            "vehicles": [], 
            "starships": [], 
            "created": "2014-12-10T16:26:56.138000Z", 
            "edited": "2014-12-20T21:17:50.330000Z", 
            "url": "https://swapi.dev/api/people/12/"
        }, 
        {
            "name": "Chewbacca", 
            "height": "228", 
            "mass": "112", 
            "hair_color": "brown", 
            "skin_color": "unknown", 
            "eye_color": "blue", 
            "birth_year": "200BBY", 
            "gender": "male", 
            "homeworld": "https://swapi.dev/api/planets/14/", 
            "films": [
                "https://swapi.dev/api/films/1/", 
                "https://swapi.dev/api/films/2/", 
                "https://swapi.dev/api/films/3/", 
                "https://swapi.dev/api/films/6/"
            ], 
            "species": [
                "https://swapi.dev/api/species/3/"
            ], 
            "vehicles": [
                "https://swapi.dev/api/vehicles/19/"
            ], 
            "starships": [
                "https://swapi.dev/api/starships/10/", 
                "https://swapi.dev/api/starships/22/"
            ], 
            "created": "2014-12-10T16:42:45.066000Z", 
            "edited": "2014-12-20T21:17:50.332000Z", 
            "url": "https://swapi.dev/api/people/13/"
        }, 
        {
            "name": "Han Solo", 
            "height": "180", 
            "mass": "80", 
            "hair_color": "brown", 
            "skin_color": "fair", 
            "eye_color": "brown", 
            "birth_year": "29BBY", 
            "gender": "male", 
            "homeworld": "https://swapi.dev/api/planets/22/", 
            "films": [
                "https://swapi.dev/api/films/1/", 
                "https://swapi.dev/api/films/2/", 
                "https://swapi.dev/api/films/3/"
            ], 
            "species": [], 
            "vehicles": [], 
            "starships": [
                "https://swapi.dev/api/starships/10/", 
                "https://swapi.dev/api/starships/22/"
            ], 
            "created": "2014-12-10T16:49:14.582000Z", 
            "edited": "2014-12-20T21:17:50.334000Z", 
            "url": "https://swapi.dev/api/people/14/"
        }, 
        {
            "name": "Greedo", 
            "height": "173", 
            "mass": "74", 
            "hair_color": "n/a", 
            "skin_color": "green", 
            "eye_color": "black", 
            "birth_year": "44BBY", 
            "gender": "male", 
            "homeworld": "https://swapi.dev/api/planets/23/", 
            "films": [
                "https://swapi.dev/api/films/1/"
            ], 
            "species": [
                "https://swapi.dev/api/species/4/"
            ], 
            "vehicles": [], 
            "starships": [], 
            "created": "2014-12-10T17:03:30.334000Z", 
            "edited": "2014-12-20T21:17:50.336000Z", 
            "url": "https://swapi.dev/api/people/15/"
        }, 
        {
            "name": "Jabba Desilijic Tiure", 
            "height": "175", 
            "mass": "1,358", 
            "hair_color": "n/a", 
            "skin_color": "green-tan, brown", 
            "eye_color": "orange", 
            "birth_year": "600BBY", 
            "gender": "hermaphrodite", 
            "homeworld": "https://swapi.dev/api/planets/24/", 
            "films": [
                "https://swapi.dev/api/films/1/", 
                "https://swapi.dev/api/films/3/", 
                "https://swapi.dev/api/films/4/"
            ], 
            "species": [
                "https://swapi.dev/api/species/5/"
            ], 
            "vehicles": [], 
            "starships": [], 
            "created": "2014-12-10T17:11:31.638000Z", 
            "edited": "2014-12-20T21:17:50.338000Z", 
            "url": "https://swapi.dev/api/people/16/"
        }, 
        {
            "name": "Wedge Antilles", 
            "height": "170", 
            "mass": "77", 
            "hair_color": "brown", 
            "skin_color": "fair", 
            "eye_color": "hazel", 
            "birth_year": "21BBY", 
            "gender": "male", 
            "homeworld": "https://swapi.dev/api/planets/22/", 
            "films": [
                "https://swapi.dev/api/films/1/", 
                "https://swapi.dev/api/films/2/", 
                "https://swapi.dev/api/films/3/"
            ], 
            "species": [], 
            "vehicles": [
                "https://swapi.dev/api/vehicles/14/"
            ], 
            "starships": [
                "https://swapi.dev/api/starships/12/"
            ], 
            "created": "2014-12-12T11:08:06.469000Z", 
            "edited": "2014-12-20T21:17:50.341000Z", 
            "url": "https://swapi.dev/api/people/18/"
        }, 
        {
            "name": "Jek Tono Porkins", 
            "height": "180", 
            "mass": "110", 
            "hair_color": "brown", 
            "skin_color": "fair", 
            "eye_color": "blue", 
            "birth_year": "unknown", 
            "gender": "male", 
            "homeworld": "https://swapi.dev/api/planets/26/", 
            "films": [
                "https://swapi.dev/api/films/1/"
            ], 
            "species": [], 
            "vehicles": [], 
            "starships": [
                "https://swapi.dev/api/starships/12/"
            ], 
            "created": "2014-12-12T11:16:56.569000Z", 
            "edited": "2014-12-20T21:17:50.343000Z", 
            "url": "https://swapi.dev/api/people/19/"
        }, 
        {
            "name": "Yoda", 
            "height": "66", 
            "mass": "17", 
            "hair_color": "white", 
            "skin_color": "green", 
            "eye_color": "brown", 
            "birth_year": "896BBY", 
            "gender": "male", 
            "homeworld": "https://swapi.dev/api/planets/28/", 
            "films": [
                "https://swapi.dev/api/films/2/", 
                "https://swapi.dev/api/films/3/", 
                "https://swapi.dev/api/films/4/", 
                "https://swapi.dev/api/films/5/", 
                "https://swapi.dev/api/films/6/"
            ], 
            "species": [
                "https://swapi.dev/api/species/6/"
            ], 
            "vehicles": [], 
            "starships": [], 
            "created": "2014-12-15T12:26:01.042000Z", 
            "edited": "2014-12-20T21:17:50.345000Z", 
            "url": "https://swapi.dev/api/people/20/"
        }, 
        {
            "name": "Palpatine", 
            "height": "170", 
            "mass": "75", 
            "hair_color": "grey", 
            "skin_color": "pale", 
            "eye_color": "yellow", 
            "birth_year": "82BBY", 
            "gender": "male", 
            "homeworld": "https://swapi.dev/api/planets/8/", 
            "films": [
                "https://swapi.dev/api/films/2/", 
                "https://swapi.dev/api/films/3/", 
                "https://swapi.dev/api/films/4/", 
                "https://swapi.dev/api/films/5/", 
                "https://swapi.dev/api/films/6/"
            ], 
            "species": [], 
            "vehicles": [], 
            "starships": [], 
            "created": "2014-12-15T12:48:05.971000Z", 
            "edited": "2014-12-20T21:17:50.347000Z", 
            "url": "https://swapi.dev/api/people/21/"
        }
    ]

# %%
# Página 2
# transformando os dados em dataframe:

# %%
df = pd.DataFrame(results_page_2)

print(df)
# Out:
#                     name height     mass    hair_color        skin_color  \
# 0       Anakin Skywalker    188       84         blond              fair
# 1         Wilhuff Tarkin    180  unknown  auburn, grey              fair
# 2              Chewbacca    228      112         brown           unknown
# 3               Han Solo    180       80         brown              fair
# 4                 Greedo    173       74           n/a             green
# 5  Jabba Desilijic Tiure    175    1,358           n/a  green-tan, brown
# 6         Wedge Antilles    170       77         brown              fair
# 7       Jek Tono Porkins    180      110         brown              fair
# 8                   Yoda     66       17         white             green
# 9              Palpatine    170       75          grey              pale
#
#   eye_color birth_year         gender                          homeworld  \
# 0      blue    41.9BBY           male   https://swapi.dev/api/planets/1/
# 1      blue      64BBY           male  https://swapi.dev/api/planets/21/
# 2      blue     200BBY           male  https://swapi.dev/api/planets/14/
# 3     brown      29BBY           male  https://swapi.dev/api/planets/22/
# 4     black      44BBY           male  https://swapi.dev/api/planets/23/
# 5    orange     600BBY  hermaphrodite  https://swapi.dev/api/planets/24/
# 6     hazel      21BBY           male  https://swapi.dev/api/planets/22/
# 7      blue    unknown           male  https://swapi.dev/api/planets/26/
# 8     brown     896BBY           male  https://swapi.dev/api/planets/28/
# 9    yellow      82BBY           male   https://swapi.dev/api/planets/8/
#
#                                                films  \
# 0  [https://swapi.dev/api/films/4/, https://swapi...
# 1  [https://swapi.dev/api/films/1/, https://swapi...
# 2  [https://swapi.dev/api/films/1/, https://swapi...
# 3  [https://swapi.dev/api/films/1/, https://swapi...
# 4                   [https://swapi.dev/api/films/1/]
# 5  [https://swapi.dev/api/films/1/, https://swapi...
# 6  [https://swapi.dev/api/films/1/, https://swapi...
# 7                   [https://swapi.dev/api/films/1/]
# 8  [https://swapi.dev/api/films/2/, https://swapi...
# 9  [https://swapi.dev/api/films/2/, https://swapi...
#
#                               species  \
# 0                                  []
# 1                                  []
# 2  [https://swapi.dev/api/species/3/]
# 3                                  []
# 4  [https://swapi.dev/api/species/4/]
# 5  [https://swapi.dev/api/species/5/]
# 6                                  []
# 7                                  []
# 8  [https://swapi.dev/api/species/6/]
# 9                                  []
#
#                                             vehicles  \
# 0  [https://swapi.dev/api/vehicles/44/, https://s...
# 1                                                 []
# 2               [https://swapi.dev/api/vehicles/19/]
# 3                                                 []
# 4                                                 []
# 5                                                 []
# 6               [https://swapi.dev/api/vehicles/14/]
# 7                                                 []
# 8                                                 []
# 9                                                 []
#
#                                            starships  \
# 0  [https://swapi.dev/api/starships/39/, https://...
# 1                                                 []
# 2  [https://swapi.dev/api/starships/10/, https://...
# 3  [https://swapi.dev/api/starships/10/, https://...
# 4                                                 []
# 5                                                 []
# 6              [https://swapi.dev/api/starships/12/]
# 7              [https://swapi.dev/api/starships/12/]
# 8                                                 []
# 9                                                 []
#
#                        created                       edited  \
# 0  2014-12-10T16:20:44.310000Z  2014-12-20T21:17:50.327000Z
# 1  2014-12-10T16:26:56.138000Z  2014-12-20T21:17:50.330000Z
# 2  2014-12-10T16:42:45.066000Z  2014-12-20T21:17:50.332000Z
# 3  2014-12-10T16:49:14.582000Z  2014-12-20T21:17:50.334000Z
# 4  2014-12-10T17:03:30.334000Z  2014-12-20T21:17:50.336000Z
# 5  2014-12-10T17:11:31.638000Z  2014-12-20T21:17:50.338000Z
# 6  2014-12-12T11:08:06.469000Z  2014-12-20T21:17:50.341000Z
# 7  2014-12-12T11:16:56.569000Z  2014-12-20T21:17:50.343000Z
# 8  2014-12-15T12:26:01.042000Z  2014-12-20T21:17:50.345000Z
# 9  2014-12-15T12:48:05.971000Z  2014-12-20T21:17:50.347000Z
#
#                                 url
# 0  https://swapi.dev/api/people/11/
# 1  https://swapi.dev/api/people/12/
# 2  https://swapi.dev/api/people/13/
# 3  https://swapi.dev/api/people/14/
# 4  https://swapi.dev/api/people/15/
# 5  https://swapi.dev/api/people/16/
# 6  https://swapi.dev/api/people/18/
# 7  https://swapi.dev/api/people/19/
# 8  https://swapi.dev/api/people/20/
# 9  https://swapi.dev/api/people/21/

# %%
# Página 2
# transformando o dataframe em tabela

# %%
df
# Out:
#                     name height     mass    hair_color        skin_color  \
# 0       Anakin Skywalker    188       84         blond              fair
# 1         Wilhuff Tarkin    180  unknown  auburn, grey              fair
# 2              Chewbacca    228      112         brown           unknown
# 3               Han Solo    180       80         brown              fair
# 4                 Greedo    173       74           n/a             green
# 5  Jabba Desilijic Tiure    175    1,358           n/a  green-tan, brown
# 6         Wedge Antilles    170       77         brown              fair
# 7       Jek Tono Porkins    180      110         brown              fair
# 8                   Yoda     66       17         white             green
# 9              Palpatine    170       75          grey              pale
#
#   eye_color birth_year         gender                          homeworld  \
# 0      blue    41.9BBY           male   https://swapi.dev/api/planets/1/
# 1      blue      64BBY           male  https://swapi.dev/api/planets/21/
# 2      blue     200BBY           male  https://swapi.dev/api/planets/14/
# 3     brown      29BBY           male  https://swapi.dev/api/planets/22/
# 4     black      44BBY           male  https://swapi.dev/api/planets/23/
# 5    orange     600BBY  hermaphrodite  https://swapi.dev/api/planets/24/
# 6     hazel      21BBY           male  https://swapi.dev/api/planets/22/
# 7      blue    unknown           male  https://swapi.dev/api/planets/26/
# 8     brown     896BBY           male  https://swapi.dev/api/planets/28/
# 9    yellow      82BBY           male   https://swapi.dev/api/planets/8/
#
#                                                films  \
# 0  [https://swapi.dev/api/films/4/, https://swapi...
# 1  [https://swapi.dev/api/films/1/, https://swapi...
# 2  [https://swapi.dev/api/films/1/, https://swapi...
# 3  [https://swapi.dev/api/films/1/, https://swapi...
# 4                   [https://swapi.dev/api/films/1/]
# 5  [https://swapi.dev/api/films/1/, https://swapi...
# 6  [https://swapi.dev/api/films/1/, https://swapi...
# 7                   [https://swapi.dev/api/films/1/]
# 8  [https://swapi.dev/api/films/2/, https://swapi...
# 9  [https://swapi.dev/api/films/2/, https://swapi...
#
#                               species  \
# 0                                  []
# 1                                  []
# 2  [https://swapi.dev/api/species/3/]
# 3                                  []
# 4  [https://swapi.dev/api/species/4/]
# 5  [https://swapi.dev/api/species/5/]
# 6                                  []
# 7                                  []
# 8  [https://swapi.dev/api/species/6/]
# 9                                  []
#
#                                             vehicles  \
# 0  [https://swapi.dev/api/vehicles/44/, https://s...
# 1                                                 []
# 2               [https://swapi.dev/api/vehicles/19/]
# 3                                                 []
# 4                                                 []
# 5                                                 []
# 6               [https://swapi.dev/api/vehicles/14/]
# 7                                                 []
# 8                                                 []
# 9                                                 []
#
#                                            starships  \
# 0  [https://swapi.dev/api/starships/39/, https://...
# 1                                                 []
# 2  [https://swapi.dev/api/starships/10/, https://...
# 3  [https://swapi.dev/api/starships/10/, https://...
# 4                                                 []
# 5                                                 []
# 6              [https://swapi.dev/api/starships/12/]
# 7              [https://swapi.dev/api/starships/12/]
# 8                                                 []
# 9                                                 []
#
#                        created                       edited  \
# 0  2014-12-10T16:20:44.310000Z  2014-12-20T21:17:50.327000Z
# 1  2014-12-10T16:26:56.138000Z  2014-12-20T21:17:50.330000Z
# 2  2014-12-10T16:42:45.066000Z  2014-12-20T21:17:50.332000Z
# 3  2014-12-10T16:49:14.582000Z  2014-12-20T21:17:50.334000Z
# 4  2014-12-10T17:03:30.334000Z  2014-12-20T21:17:50.336000Z
# 5  2014-12-10T17:11:31.638000Z  2014-12-20T21:17:50.338000Z
# 6  2014-12-12T11:08:06.469000Z  2014-12-20T21:17:50.341000Z
# 7  2014-12-12T11:16:56.569000Z  2014-12-20T21:17:50.343000Z
# 8  2014-12-15T12:26:01.042000Z  2014-12-20T21:17:50.345000Z
# 9  2014-12-15T12:48:05.971000Z  2014-12-20T21:17:50.347000Z
#
#                                 url
# 0  https://swapi.dev/api/people/11/
# 1  https://swapi.dev/api/people/12/
# 2  https://swapi.dev/api/people/13/
# 3  https://swapi.dev/api/people/14/
# 4  https://swapi.dev/api/people/15/
# 5  https://swapi.dev/api/people/16/
# 6  https://swapi.dev/api/people/18/
# 7  https://swapi.dev/api/people/19/
# 8  https://swapi.dev/api/people/20/
# 9  https://swapi.dev/api/people/21/

# %%
# Página 2
# selecionando os dados solicitados: nome e cor da pele

# %%
nome_e_cor_da_pele = df[['name', 'skin_color']]
display(nome_e_cor_da_pele)
# Out:
#                     name        skin_color
# 0       Anakin Skywalker              fair
# 1         Wilhuff Tarkin              fair
# 2              Chewbacca           unknown
# 3               Han Solo              fair
# 4                 Greedo             green
# 5  Jabba Desilijic Tiure  green-tan, brown
# 6         Wedge Antilles              fair
# 7       Jek Tono Porkins              fair
# 8                   Yoda             green
# 9              Palpatine              pale

# %%
# Página 2
# Colunas com as propriedades e seus respectivos valores, de acordo com o retorno da api nome , altura, peso, aniversário e gênero.

# %%
nome_altura_peso_aniversario_genero = df[['name', 'height', 'mass', 'birth_year', 'gender' ]]
display(nome_altura_peso_aniversario_genero)
# Out:
#                     name height     mass birth_year         gender
# 0       Anakin Skywalker    188       84    41.9BBY           male
# 1         Wilhuff Tarkin    180  unknown      64BBY           male
# 2              Chewbacca    228      112     200BBY           male
# 3               Han Solo    180       80      29BBY           male
# 4                 Greedo    173       74      44BBY           male
# 5  Jabba Desilijic Tiure    175    1,358     600BBY  hermaphrodite
# 6         Wedge Antilles    170       77      21BBY           male
# 7       Jek Tono Porkins    180      110    unknown           male
# 8                   Yoda     66       17     896BBY           male
# 9              Palpatine    170       75      82BBY           male

# %%
# transformando a tabela python completa em uma tabela HTML ( para construir as páginas)

# %%
html=df.to_html()
print(html)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>height</th>
#       <th>mass</th>
#       <th>hair_color</th>
#       <th>skin_color</th>
#       <th>eye_color</th>
#       <th>birth_year</th>
#       <th>gender</th>
#       <th>homeworld</th>
#       <th>films</th>
#       <th>species</th>
#       <th>vehicles</th>
#       <th>starships</th>
#       <th>created</th>
#       <th>edited</th>
#       <th>url</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Anakin Skywalker</td>
#       <td>188</td>
#       <td>84</td>
#       <td>blond</td>
#       <td>fair</td>
#       <td>blue</td>
#       <td>41.9BBY</td>
#       <td>male</td>
#       <td>https://swapi.dev/api/planets/1/</td>
#       <td>[https://swapi.dev/api/films/4/, https://swapi.dev/api/films/5/, https://swapi.dev/api/films/6/]</td>
#       <td>[]</td>
#       <td>[https://swapi.dev/api/vehicles/44/, https://swapi.dev/api/vehicles/46/]</td>
#       <td>[https://swapi.dev/api/starships/39/, https://swapi.dev/api/starships/59/, https://swapi.dev/api/starships/65/]</td>
#       <td>2014-12-10T16:20:44.310000Z</td>
#       <td>2014-12-20T21:17:50.327000Z</td>
#       <td>https://swapi.dev/api/people/11/</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Wilhuff Tarkin</td>
#       <td>180</td>
#       <td>unknown</td>
#       <td>auburn, grey</td>
#       <td>fair</td>
#       <td>blue</td>
#       <td>64BBY</td>
#       <td>male</td>
#       <td>https://swapi.dev/api/planets/21/</td>
#       <td>[https://swapi.dev/api/films/1/, https://swapi.dev/api/films/6/]</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>2014-12-10T16:26:56.138000Z</td>
#       <td>2014-12-20T21:17:50.330000Z</td>
#       <td>https://swapi.dev/api/people/12/</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Chewbacca</td>
#       <td>228</td>
#       <td>112</td>
#       <td>brown</td>
#       <td>unknown</td>
#       <td>blue</td>
#       <td>200BBY</td>
#       <td>male</td>
#       <td>https://swapi.dev/api/planets/14/</td>
#       <td>[https://swapi.dev/api/films/1/, https://swapi.dev/api/films/2/, https://swapi.dev/api/films/3/, https://swapi.dev/api/films/6/]</td>
#       <td>[https://swapi.dev/api/species/3/]</td>
#       <td>[https://swapi.dev/api/vehicles/19/]</td>
#       <td>[https://swapi.dev/api/starships/10/, https://swapi.dev/api/starships/22/]</td>
#       <td>2014-12-10T16:42:45.066000Z</td>
#       <td>2014-12-20T21:17:50.332000Z</td>
#       <td>https://swapi.dev/api/people/13/</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Han Solo</td>
#       <td>180</td>
#       <td>80</td>
#       <td>brown</td>
#       <td>fair</td>
#       <td>brown</td>
#       <td>29BBY</td>
#       <td>male</td>
#       <td>https://swapi.dev/api/planets/22/</td>
#       <td>[https://swapi.dev/api/films/1/, https://swapi.dev/api/films/2/, https://swapi.dev/api/films/3/]</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>[https://swapi.dev/api/starships/10/, https://swapi.dev/api/starships/22/]</td>
#       <td>2014-12-10T16:49:14.582000Z</td>
#       <td>2014-12-20T21:17:50.334000Z</td>
#       <td>https://swapi.dev/api/people/14/</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Greedo</td>
#       <td>173</td>
#       <td>74</td>
#       <td>n/a</td>
#       <td>green</td>
#       <td>black</td>
#       <td>44BBY</td>
#       <td>male</td>
#       <td>https://swapi.dev/api/planets/23/</td>
#       <td>[https://swapi.dev/api/films/1/]</td>
#       <td>[https://swapi.dev/api/species/4/]</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>2014-12-10T17:03:30.334000Z</td>
#       <td>2014-12-20T21:17:50.336000Z</td>
#       <td>https://swapi.dev/api/people/15/</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Jabba Desilijic Tiure</td>
#       <td>175</td>
#       <td>1,358</td>
#       <td>n/a</td>
#       <td>green-tan, brown</td>
#       <td>orange</td>
#       <td>600BBY</td>
#       <td>hermaphrodite</td>
#       <td>https://swapi.dev/api/planets/24/</td>
#       <td>[https://swapi.dev/api/films/1/, https://swapi.dev/api/films/3/, https://swapi.dev/api/films/4/]</td>
#       <td>[https://swapi.dev/api/species/5/]</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>2014-12-10T17:11:31.638000Z</td>
#       <td>2014-12-20T21:17:50.338000Z</td>
#       <td>https://swapi.dev/api/people/16/</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Wedge Antilles</td>
#       <td>170</td>
#       <td>77</td>
#       <td>brown</td>
#       <td>fair</td>
#       <td>hazel</td>
#       <td>21BBY</td>
#       <td>male</td>
#       <td>https://swapi.dev/api/planets/22/</td>
#       <td>[https://swapi.dev/api/films/1/, https://swapi.dev/api/films/2/, https://swapi.dev/api/films/3/]</td>
#       <td>[]</td>
#       <td>[https://swapi.dev/api/vehicles/14/]</td>
#       <td>[https://swapi.dev/api/starships/12/]</td>
#       <td>2014-12-12T11:08:06.469000Z</td>
#       <td>2014-12-20T21:17:50.341000Z</td>
#       <td>https://swapi.dev/api/people/18/</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Jek Tono Porkins</td>
#       <td>180</td>
#       <td>110</td>
#       <td>brown</td>
#       <td>fair</td>
#       <td>blue</td>
#       <td>unknown</td>
#       <td>male</td>
#       <td>https://swapi.dev/api/planets/26/</td>
#       <td>[https://swapi.dev/api/films/1/]</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>[https://swapi.dev/api/starships/12/]</td>
#       <td>2014-12-12T11:16:56.569000Z</td>
#       <td>2014-12-20T21:17:50.343000Z</td>
#       <td>https://swapi.dev/api/people/19/</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Yoda</td>
#       <td>66</td>
#       <td>17</td>
#       <td>white</td>
#       <td>green</td>
#       <td>brown</td>
#       <td>896BBY</td>
#       <td>male</td>
#       <td>https://swapi.dev/api/planets/28/</td>
#       <td>[https://swapi.dev/api/films/2/, https://swapi.dev/api/films/3/, https://swapi.dev/api/films/4/, https://swapi.dev/api/films/5/, https://swapi.dev/api/films/6/]</td>
#       <td>[https://swapi.dev/api/species/6/]</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>2014-12-15T12:26:01.042000Z</td>
#       <td>2014-12-20T21:17:50.345000Z</td>
#       <td>https://swapi.dev/api/people/20/</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Palpatine</td>
#       <td>170</td>
#       <td>75</td>
#       <td>grey</td>
#       <td>pale</td>
#       <td>yellow</td>
#       <td>82BBY</td>
#       <td>male</td>
#       <td>https://swapi.dev/api/planets/8/</td>
#       <td>[https://swapi.dev/api/films/2/, https://swapi.dev/api/films/3/, https://swapi.dev/api/films/4/, https://swapi.dev/api/films/5/, https://swapi.dev/api/films/6/]</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>2014-12-15T12:48:05.971000Z</td>
#       <td>2014-12-20T21:17:50.347000Z</td>
#       <td>https://swapi.dev/api/people/21/</td>
#     </tr>
#   </tbody>
# </table>

# %%
#exportando a tabela escrita em html para arquivo html:

# %%
arq = open("tabela_pagina_2.html", "w")
arq = arq.write(html)

# %%
#organizando os dados de cada pessoa

# %%
df.values.tolist()
# Out:
# [['Anakin Skywalker',
#   '188',
#   '84',
#   'blond',
#   'fair',
#   'blue',
#   '41.9BBY',
#   'male',
#   'https://swapi.dev/api/planets/1/',
#   ['https://swapi.dev/api/films/4/',
#    'https://swapi.dev/api/films/5/',
#    'https://swapi.dev/api/films/6/'],
#   [],
#   ['https://swapi.dev/api/vehicles/44/', 'https://swapi.dev/api/vehicles/46/'],
#   ['https://swapi.dev/api/starships/39/',
#    'https://swapi.dev/api/starships/59/',
#    'https://swapi.dev/api/starships/65/'],
#   '2014-12-10T16:20:44.310000Z',
#   '2014-12-20T21:17:50.327000Z',
#   'https://swapi.dev/api/people/11/'],
#  ['Wilhuff Tarkin',
#   '180',
#   'unknown',
#   'auburn, grey',
#   'fair',
#   'blue',
#   '64BBY',
#   'male',
#   'https://swapi.dev/api/planets/21/',
#   ['https://swapi.dev/api/films/1/', 'https://swapi.dev/api/films/6/'],
#   [],
#   [],
#   [],
#   '2014-12-10T16:26:56.138000Z',
#   '2014-12-20T21:17:50.330000Z',
#   'https://swapi.dev/api/people/12/'],
#  ['Chewbacca',
#   '228',
#   '112',
#   'brown',
#   'unknown',
#   'blue',
#   '200BBY',
#   'male',
#   'https://swapi.dev/api/planets/14/',
#   ['https://swapi.dev/api/films/1/',
#    'https://swapi.dev/api/films/2/',
#    'https://swapi.dev/api/films/3/',
#    'https://swapi.dev/api/films/6/'],
#   ['https://swapi.dev/api/species/3/'],
#   ['https://swapi.dev/api/vehicles/19/'],
#   ['https://swapi.dev/api/starships/10/',
#    'https://swapi.dev/api/starships/22/'],
#   '2014-12-10T16:42:45.066000Z',
#   '2014-12-20T21:17:50.332000Z',
#   'https://swapi.dev/api/people/13/'],
#  ['Han Solo',
#   '180',
#   '80',
#   'brown',
#   'fair',
#   'brown',
#   '29BBY',
#   'male',
#   'https://swapi.dev/api/planets/22/',
#   ['https://swapi.dev/api/films/1/',
#    'https://swapi.dev/api/films/2/',
#    'https://swapi.dev/api/films/3/'],
#   [],
#   [],
#   ['https://swapi.dev/api/starships/10/',
#    'https://swapi.dev/api/starships/22/'],
#   '2014-12-10T16:49:14.582000Z',
#   '2014-12-20T21:17:50.334000Z',
#   'https://swapi.dev/api/people/14/'],
#  ['Greedo',
#   '173',
#   '74',
#   'n/a',
#   'green',
#   'black',
#   '44BBY',
#   'male',
#   'https://swapi.dev/api/planets/23/',
#   ['https://swapi.dev/api/films/1/'],
#   ['https://swapi.dev/api/species/4/'],
#   [],
#   [],
#   '2014-12-10T17:03:30.334000Z',
#   '2014-12-20T21:17:50.336000Z',
#   'https://swapi.dev/api/people/15/'],
#  ['Jabba Desilijic Tiure',
#   '175',
#   '1,358',
#   'n/a',
#   'green-tan, brown',
#   'orange',
#   '600BBY',
#   'hermaphrodite',
#   'https://swapi.dev/api/planets/24/',
#   ['https://swapi.dev/api/films/1/',
#    'https://swapi.dev/api/films/3/',
#    'https://swapi.dev/api/films/4/'],
#   ['https://swapi.dev/api/species/5/'],
#   [],
#   [],
#   '2014-12-10T17:11:31.638000Z',
#   '2014-12-20T21:17:50.338000Z',
#   'https://swapi.dev/api/people/16/'],
#  ['Wedge Antilles',
#   '170',
#   '77',
#   'brown',
#   'fair',
#   'hazel',
#   '21BBY',
#   'male',
#   'https://swapi.dev/api/planets/22/',
#   ['https://swapi.dev/api/films/1/',
#    'https://swapi.dev/api/films/2/',
#    'https://swapi.dev/api/films/3/'],
#   [],
#   ['https://swapi.dev/api/vehicles/14/'],
#   ['https://swapi.dev/api/starships/12/'],
#   '2014-12-12T11:08:06.469000Z',
#   '2014-12-20T21:17:50.341000Z',
#   'https://swapi.dev/api/people/18/'],
#  ['Jek Tono Porkins',
#   '180',
#   '110',
#   'brown',
#   'fair',
#   'blue',
#   'unknown',
#   'male',
#   'https://swapi.dev/api/planets/26/',
#   ['https://swapi.dev/api/films/1/'],
#   [],
#   [],
#   ['https://swapi.dev/api/starships/12/'],
#   '2014-12-12T11:16:56.569000Z',
#   '2014-12-20T21:17:50.343000Z',
#   'https://swapi.dev/api/people/19/'],
#  ['Yoda',
#   '66',
#   '17',
#   'white',
#   'green',
#   'brown',
#   '896BBY',
#   'male',
#   'https://swapi.dev/api/planets/28/',
#   ['https://swapi.dev/api/films/2/',
#    'https://swapi.dev/api/films/3/',
#    'https://swapi.dev/api/films/4/',
#    'https://swapi.dev/api/films/5/',
#    'https://swapi.dev/api/films/6/'],
#   ['https://swapi.dev/api/species/6/'],
#   [],
#   [],
#   '2014-12-15T12:26:01.042000Z',
#   '2014-12-20T21:17:50.345000Z',
#   'https://swapi.dev/api/people/20/'],
#  ['Palpatine',
#   '170',
#   '75',
#   'grey',
#   'pale',
#   'yellow',
#   '82BBY',
#   'male',
#   'https://swapi.dev/api/planets/8/',
#   ['https://swapi.dev/api/films/2/',
#    'https://swapi.dev/api/films/3/',
#    'https://swapi.dev/api/films/4/',
#    'https://swapi.dev/api/films/5/',
#    'https://swapi.dev/api/films/6/'],
#   [],
#   [],
#   [],
#   '2014-12-15T12:48:05.971000Z',
#   '2014-12-20T21:17:50.347000Z',
#   'https://swapi.dev/api/people/21/']]

# %%
# Página 2
#Catalogando as cores de pele desta página 2:

# %%
cor_da_pele = df[['skin_color']]
display(cor_da_pele)
# Out:
#          skin_color
# 0              fair
# 1              fair
# 2           unknown
# 3              fair
# 4             green
# 5  green-tan, brown
# 6              fair
# 7              fair
# 8             green
# 9              pale

# %%
# Página 2
# Organizando a lista das cores de pele

# %%
listacordapele = cor_da_pele ["skin_color"].tolist()
print(listacordapele)
# Out:
# ['fair', 'fair', 'unknown', 'fair', 'green', 'green-tan, brown', 'fair', 'fair', 'green', 'pale']

# %%
# Página 2
# Eliminando da lista as cores de pele repetidas:

# %%
cor_da_pele_nao_repetida = {'fair', 'fair', 'unknown', 'fair', 'green', 'green-tan, brown', 'fair', 'fair', 'green', 'pale'}
print(cor_da_pele_nao_repetida)
# Out:
# {'fair', 'green', 'green-tan, brown', 'unknown', 'pale'}
