# %%
import pandas as pd
import numpy as np

# %%
# Página 6 (https://swapi.dev/api/people/?page=6)
# capturando a lista de pessoas, para compor a tabela:

# %%
results_page_6 = [
     {
            "name": "Ki-Adi-Mundi", 
            "height": "198", 
            "mass": "82", 
            "hair_color": "white", 
            "skin_color": "pale", 
            "eye_color": "yellow", 
            "birth_year": "92BBY", 
            "gender": "male", 
            "homeworld": "https://swapi.dev/api/planets/43/", 
            "films": [
                "https://swapi.dev/api/films/4/", 
                "https://swapi.dev/api/films/5/", 
                "https://swapi.dev/api/films/6/"
            ], 
            "species": [
                "https://swapi.dev/api/species/20/"
            ], 
            "vehicles": [], 
            "starships": [], 
            "created": "2014-12-20T10:15:32.293000Z", 
            "edited": "2014-12-20T21:17:50.422000Z", 
            "url": "https://swapi.dev/api/people/52/"
        }, 
        {
            "name": "Kit Fisto", 
            "height": "196", 
            "mass": "87", 
            "hair_color": "none", 
            "skin_color": "green", 
            "eye_color": "black", 
            "birth_year": "unknown", 
            "gender": "male", 
            "homeworld": "https://swapi.dev/api/planets/44/", 
            "films": [
                "https://swapi.dev/api/films/4/", 
                "https://swapi.dev/api/films/5/", 
                "https://swapi.dev/api/films/6/"
            ], 
            "species": [
                "https://swapi.dev/api/species/21/"
            ], 
            "vehicles": [], 
            "starships": [], 
            "created": "2014-12-20T10:18:57.202000Z", 
            "edited": "2014-12-20T21:17:50.424000Z", 
            "url": "https://swapi.dev/api/people/53/"
        }, 
        {
            "name": "Eeth Koth", 
            "height": "171", 
            "mass": "unknown", 
            "hair_color": "black", 
            "skin_color": "brown", 
            "eye_color": "brown", 
            "birth_year": "unknown", 
            "gender": "male", 
            "homeworld": "https://swapi.dev/api/planets/45/", 
            "films": [
                "https://swapi.dev/api/films/4/", 
                "https://swapi.dev/api/films/6/"
            ], 
            "species": [
                "https://swapi.dev/api/species/22/"
            ], 
            "vehicles": [], 
            "starships": [], 
            "created": "2014-12-20T10:26:47.902000Z", 
            "edited": "2014-12-20T21:17:50.427000Z", 
            "url": "https://swapi.dev/api/people/54/"
        }, 
        {
            "name": "Adi Gallia", 
            "height": "184", 
            "mass": "50", 
            "hair_color": "none", 
            "skin_color": "dark", 
            "eye_color": "blue", 
            "birth_year": "unknown", 
            "gender": "female", 
            "homeworld": "https://swapi.dev/api/planets/9/", 
            "films": [
                "https://swapi.dev/api/films/4/", 
                "https://swapi.dev/api/films/6/"
            ], 
            "species": [
                "https://swapi.dev/api/species/23/"
            ], 
            "vehicles": [], 
            "starships": [], 
            "created": "2014-12-20T10:29:11.661000Z", 
            "edited": "2014-12-20T21:17:50.432000Z", 
            "url": "https://swapi.dev/api/people/55/"
        }, 
        {
            "name": "Saesee Tiin", 
            "height": "188", 
            "mass": "unknown", 
            "hair_color": "none", 
            "skin_color": "pale", 
            "eye_color": "orange", 
            "birth_year": "unknown", 
            "gender": "male", 
            "homeworld": "https://swapi.dev/api/planets/47/", 
            "films": [
                "https://swapi.dev/api/films/4/", 
                "https://swapi.dev/api/films/6/"
            ], 
            "species": [
                "https://swapi.dev/api/species/24/"
            ], 
            "vehicles": [], 
            "starships": [], 
            "created": "2014-12-20T10:32:11.669000Z", 
            "edited": "2014-12-20T21:17:50.434000Z", 
            "url": "https://swapi.dev/api/people/56/"
        }, 
        {
            "name": "Yarael Poof", 
            "height": "264", 
            "mass": "unknown", 
            "hair_color": "none", 
            "skin_color": "white", 
            "eye_color": "yellow", 
            "birth_year": "unknown", 
            "gender": "male", 
            "homeworld": "https://swapi.dev/api/planets/48/", 
            "films": [
                "https://swapi.dev/api/films/4/"
            ], 
            "species": [
                "https://swapi.dev/api/species/25/"
            ], 
            "vehicles": [], 
            "starships": [], 
            "created": "2014-12-20T10:34:48.725000Z", 
            "edited": "2014-12-20T21:17:50.437000Z", 
            "url": "https://swapi.dev/api/people/57/"
        }, 
        {
            "name": "Plo Koon", 
            "height": "188", 
            "mass": "80", 
            "hair_color": "none", 
            "skin_color": "orange", 
            "eye_color": "black", 
            "birth_year": "22BBY", 
            "gender": "male", 
            "homeworld": "https://swapi.dev/api/planets/49/", 
            "films": [
                "https://swapi.dev/api/films/4/", 
                "https://swapi.dev/api/films/5/", 
                "https://swapi.dev/api/films/6/"
            ], 
            "species": [
                "https://swapi.dev/api/species/26/"
            ], 
            "vehicles": [], 
            "starships": [
                "https://swapi.dev/api/starships/48/"
            ], 
            "created": "2014-12-20T10:49:19.859000Z", 
            "edited": "2014-12-20T21:17:50.439000Z", 
            "url": "https://swapi.dev/api/people/58/"
        }, 
        {
            "name": "Mas Amedda", 
            "height": "196", 
            "mass": "unknown", 
            "hair_color": "none", 
            "skin_color": "blue", 
            "eye_color": "blue", 
            "birth_year": "unknown", 
            "gender": "male", 
            "homeworld": "https://swapi.dev/api/planets/50/", 
            "films": [
                "https://swapi.dev/api/films/4/", 
                "https://swapi.dev/api/films/5/"
            ], 
            "species": [
                "https://swapi.dev/api/species/27/"
            ], 
            "vehicles": [], 
            "starships": [], 
            "created": "2014-12-20T10:53:26.457000Z", 
            "edited": "2014-12-20T21:17:50.442000Z", 
            "url": "https://swapi.dev/api/people/59/"
        }, 
        {
            "name": "Gregar Typho", 
            "height": "185", 
            "mass": "85", 
            "hair_color": "black", 
            "skin_color": "dark", 
            "eye_color": "brown", 
            "birth_year": "unknown", 
            "gender": "male", 
            "homeworld": "https://swapi.dev/api/planets/8/", 
            "films": [
                "https://swapi.dev/api/films/5/"
            ], 
            "species": [], 
            "vehicles": [], 
            "starships": [
                "https://swapi.dev/api/starships/39/"
            ], 
            "created": "2014-12-20T11:10:10.381000Z", 
            "edited": "2014-12-20T21:17:50.445000Z", 
            "url": "https://swapi.dev/api/people/60/"
        }, 
        {
            "name": "Cordé", 
            "height": "157", 
            "mass": "unknown", 
            "hair_color": "brown", 
            "skin_color": "light", 
            "eye_color": "brown", 
            "birth_year": "unknown", 
            "gender": "female", 
            "homeworld": "https://swapi.dev/api/planets/8/", 
            "films": [
                "https://swapi.dev/api/films/5/"
            ], 
            "species": [], 
            "vehicles": [], 
            "starships": [], 
            "created": "2014-12-20T11:11:39.630000Z", 
            "edited": "2014-12-20T21:17:50.449000Z", 
            "url": "https://swapi.dev/api/people/61/"
        }
    ]

# %%
# Página 6
# transformando os dados em dataframe:

# %%
df = pd.DataFrame(results_page_6)

print(df)
# Out:
#            name height     mass hair_color skin_color eye_color birth_year  \
# 0  Ki-Adi-Mundi    198       82      white       pale    yellow      92BBY
# 1     Kit Fisto    196       87       none      green     black    unknown
# 2     Eeth Koth    171  unknown      black      brown     brown    unknown
# 3    Adi Gallia    184       50       none       dark      blue    unknown
# 4   Saesee Tiin    188  unknown       none       pale    orange    unknown
# 5   Yarael Poof    264  unknown       none      white    yellow    unknown
# 6      Plo Koon    188       80       none     orange     black      22BBY
# 7    Mas Amedda    196  unknown       none       blue      blue    unknown
# 8  Gregar Typho    185       85      black       dark     brown    unknown
# 9         Cordé    157  unknown      brown      light     brown    unknown
#
#    gender                          homeworld  \
# 0    male  https://swapi.dev/api/planets/43/
# 1    male  https://swapi.dev/api/planets/44/
# 2    male  https://swapi.dev/api/planets/45/
# 3  female   https://swapi.dev/api/planets/9/
# 4    male  https://swapi.dev/api/planets/47/
# 5    male  https://swapi.dev/api/planets/48/
# 6    male  https://swapi.dev/api/planets/49/
# 7    male  https://swapi.dev/api/planets/50/
# 8    male   https://swapi.dev/api/planets/8/
# 9  female   https://swapi.dev/api/planets/8/
#
#                                                films  \
# 0  [https://swapi.dev/api/films/4/, https://swapi...
# 1  [https://swapi.dev/api/films/4/, https://swapi...
# 2  [https://swapi.dev/api/films/4/, https://swapi...
# 3  [https://swapi.dev/api/films/4/, https://swapi...
# 4  [https://swapi.dev/api/films/4/, https://swapi...
# 5                   [https://swapi.dev/api/films/4/]
# 6  [https://swapi.dev/api/films/4/, https://swapi...
# 7  [https://swapi.dev/api/films/4/, https://swapi...
# 8                   [https://swapi.dev/api/films/5/]
# 9                   [https://swapi.dev/api/films/5/]
#
#                                species vehicles  \
# 0  [https://swapi.dev/api/species/20/]       []
# 1  [https://swapi.dev/api/species/21/]       []
# 2  [https://swapi.dev/api/species/22/]       []
# 3  [https://swapi.dev/api/species/23/]       []
# 4  [https://swapi.dev/api/species/24/]       []
# 5  [https://swapi.dev/api/species/25/]       []
# 6  [https://swapi.dev/api/species/26/]       []
# 7  [https://swapi.dev/api/species/27/]       []
# 8                                   []       []
# 9                                   []       []
#
#                                starships                      created  \
# 0                                     []  2014-12-20T10:15:32.293000Z
# 1                                     []  2014-12-20T10:18:57.202000Z
# 2                                     []  2014-12-20T10:26:47.902000Z
# 3                                     []  2014-12-20T10:29:11.661000Z
# 4                                     []  2014-12-20T10:32:11.669000Z
# 5                                     []  2014-12-20T10:34:48.725000Z
# 6  [https://swapi.dev/api/starships/48/]  2014-12-20T10:49:19.859000Z
# 7                                     []  2014-12-20T10:53:26.457000Z
# 8  [https://swapi.dev/api/starships/39/]  2014-12-20T11:10:10.381000Z
# 9                                     []  2014-12-20T11:11:39.630000Z
#
#                         edited                               url
# 0  2014-12-20T21:17:50.422000Z  https://swapi.dev/api/people/52/
# 1  2014-12-20T21:17:50.424000Z  https://swapi.dev/api/people/53/
# 2  2014-12-20T21:17:50.427000Z  https://swapi.dev/api/people/54/
# 3  2014-12-20T21:17:50.432000Z  https://swapi.dev/api/people/55/
# 4  2014-12-20T21:17:50.434000Z  https://swapi.dev/api/people/56/
# 5  2014-12-20T21:17:50.437000Z  https://swapi.dev/api/people/57/
# 6  2014-12-20T21:17:50.439000Z  https://swapi.dev/api/people/58/
# 7  2014-12-20T21:17:50.442000Z  https://swapi.dev/api/people/59/
# 8  2014-12-20T21:17:50.445000Z  https://swapi.dev/api/people/60/
# 9  2014-12-20T21:17:50.449000Z  https://swapi.dev/api/people/61/

# %%
# Página 6
# transformando o dataframe em tabela

# %%
df
# Out:
#            name height     mass hair_color skin_color eye_color birth_year  \
# 0  Ki-Adi-Mundi    198       82      white       pale    yellow      92BBY
# 1     Kit Fisto    196       87       none      green     black    unknown
# 2     Eeth Koth    171  unknown      black      brown     brown    unknown
# 3    Adi Gallia    184       50       none       dark      blue    unknown
# 4   Saesee Tiin    188  unknown       none       pale    orange    unknown
# 5   Yarael Poof    264  unknown       none      white    yellow    unknown
# 6      Plo Koon    188       80       none     orange     black      22BBY
# 7    Mas Amedda    196  unknown       none       blue      blue    unknown
# 8  Gregar Typho    185       85      black       dark     brown    unknown
# 9         Cordé    157  unknown      brown      light     brown    unknown
#
#    gender                          homeworld  \
# 0    male  https://swapi.dev/api/planets/43/
# 1    male  https://swapi.dev/api/planets/44/
# 2    male  https://swapi.dev/api/planets/45/
# 3  female   https://swapi.dev/api/planets/9/
# 4    male  https://swapi.dev/api/planets/47/
# 5    male  https://swapi.dev/api/planets/48/
# 6    male  https://swapi.dev/api/planets/49/
# 7    male  https://swapi.dev/api/planets/50/
# 8    male   https://swapi.dev/api/planets/8/
# 9  female   https://swapi.dev/api/planets/8/
#
#                                                films  \
# 0  [https://swapi.dev/api/films/4/, https://swapi...
# 1  [https://swapi.dev/api/films/4/, https://swapi...
# 2  [https://swapi.dev/api/films/4/, https://swapi...
# 3  [https://swapi.dev/api/films/4/, https://swapi...
# 4  [https://swapi.dev/api/films/4/, https://swapi...
# 5                   [https://swapi.dev/api/films/4/]
# 6  [https://swapi.dev/api/films/4/, https://swapi...
# 7  [https://swapi.dev/api/films/4/, https://swapi...
# 8                   [https://swapi.dev/api/films/5/]
# 9                   [https://swapi.dev/api/films/5/]
#
#                                species vehicles  \
# 0  [https://swapi.dev/api/species/20/]       []
# 1  [https://swapi.dev/api/species/21/]       []
# 2  [https://swapi.dev/api/species/22/]       []
# 3  [https://swapi.dev/api/species/23/]       []
# 4  [https://swapi.dev/api/species/24/]       []
# 5  [https://swapi.dev/api/species/25/]       []
# 6  [https://swapi.dev/api/species/26/]       []
# 7  [https://swapi.dev/api/species/27/]       []
# 8                                   []       []
# 9                                   []       []
#
#                                starships                      created  \
# 0                                     []  2014-12-20T10:15:32.293000Z
# 1                                     []  2014-12-20T10:18:57.202000Z
# 2                                     []  2014-12-20T10:26:47.902000Z
# 3                                     []  2014-12-20T10:29:11.661000Z
# 4                                     []  2014-12-20T10:32:11.669000Z
# 5                                     []  2014-12-20T10:34:48.725000Z
# 6  [https://swapi.dev/api/starships/48/]  2014-12-20T10:49:19.859000Z
# 7                                     []  2014-12-20T10:53:26.457000Z
# 8  [https://swapi.dev/api/starships/39/]  2014-12-20T11:10:10.381000Z
# 9                                     []  2014-12-20T11:11:39.630000Z
#
#                         edited                               url
# 0  2014-12-20T21:17:50.422000Z  https://swapi.dev/api/people/52/
# 1  2014-12-20T21:17:50.424000Z  https://swapi.dev/api/people/53/
# 2  2014-12-20T21:17:50.427000Z  https://swapi.dev/api/people/54/
# 3  2014-12-20T21:17:50.432000Z  https://swapi.dev/api/people/55/
# 4  2014-12-20T21:17:50.434000Z  https://swapi.dev/api/people/56/
# 5  2014-12-20T21:17:50.437000Z  https://swapi.dev/api/people/57/
# 6  2014-12-20T21:17:50.439000Z  https://swapi.dev/api/people/58/
# 7  2014-12-20T21:17:50.442000Z  https://swapi.dev/api/people/59/
# 8  2014-12-20T21:17:50.445000Z  https://swapi.dev/api/people/60/
# 9  2014-12-20T21:17:50.449000Z  https://swapi.dev/api/people/61/

# %%
# Página 6
# selecionando os dados solicitados: nome e cor da pele

# %%
nome_e_cor_da_pele = df[['name', 'skin_color']]
display(nome_e_cor_da_pele)
# Out:
#            name skin_color
# 0  Ki-Adi-Mundi       pale
# 1     Kit Fisto      green
# 2     Eeth Koth      brown
# 3    Adi Gallia       dark
# 4   Saesee Tiin       pale
# 5   Yarael Poof      white
# 6      Plo Koon     orange
# 7    Mas Amedda       blue
# 8  Gregar Typho       dark
# 9         Cordé      light

# %%
# Página 6
# Colunas com as propriedades e seus respectivos valores, de acordo com o retorno da api nome , altura, peso, aniversário e gênero.

# %%
nome_altura_peso_aniversario_genero = df[['name', 'height', 'mass', 'birth_year', 'gender' ]]
display(nome_altura_peso_aniversario_genero)
# Out:
#            name height     mass birth_year  gender
# 0  Ki-Adi-Mundi    198       82      92BBY    male
# 1     Kit Fisto    196       87    unknown    male
# 2     Eeth Koth    171  unknown    unknown    male
# 3    Adi Gallia    184       50    unknown  female
# 4   Saesee Tiin    188  unknown    unknown    male
# 5   Yarael Poof    264  unknown    unknown    male
# 6      Plo Koon    188       80      22BBY    male
# 7    Mas Amedda    196  unknown    unknown    male
# 8  Gregar Typho    185       85    unknown    male
# 9         Cordé    157  unknown    unknown  female

# %%
# transformando a tabela python completa em uma tabela HTML (para construir as páginas)

# %%
html=df.to_html()
print(html)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>height</th>
#       <th>mass</th>
#       <th>hair_color</th>
#       <th>skin_color</th>
#       <th>eye_color</th>
#       <th>birth_year</th>
#       <th>gender</th>
#       <th>homeworld</th>
#       <th>films</th>
#       <th>species</th>
#       <th>vehicles</th>
#       <th>starships</th>
#       <th>created</th>
#       <th>edited</th>
#       <th>url</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Ki-Adi-Mundi</td>
#       <td>198</td>
#       <td>82</td>
#       <td>white</td>
#       <td>pale</td>
#       <td>yellow</td>
#       <td>92BBY</td>
#       <td>male</td>
#       <td>https://swapi.dev/api/planets/43/</td>
#       <td>[https://swapi.dev/api/films/4/, https://swapi.dev/api/films/5/, https://swapi.dev/api/films/6/]</td>
#       <td>[https://swapi.dev/api/species/20/]</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>2014-12-20T10:15:32.293000Z</td>
#       <td>2014-12-20T21:17:50.422000Z</td>
#       <td>https://swapi.dev/api/people/52/</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Kit Fisto</td>
#       <td>196</td>
#       <td>87</td>
#       <td>none</td>
#       <td>green</td>
#       <td>black</td>
#       <td>unknown</td>
#       <td>male</td>
#       <td>https://swapi.dev/api/planets/44/</td>
#       <td>[https://swapi.dev/api/films/4/, https://swapi.dev/api/films/5/, https://swapi.dev/api/films/6/]</td>
#       <td>[https://swapi.dev/api/species/21/]</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>2014-12-20T10:18:57.202000Z</td>
#       <td>2014-12-20T21:17:50.424000Z</td>
#       <td>https://swapi.dev/api/people/53/</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Eeth Koth</td>
#       <td>171</td>
#       <td>unknown</td>
#       <td>black</td>
#       <td>brown</td>
#       <td>brown</td>
#       <td>unknown</td>
#       <td>male</td>
#       <td>https://swapi.dev/api/planets/45/</td>
#       <td>[https://swapi.dev/api/films/4/, https://swapi.dev/api/films/6/]</td>
#       <td>[https://swapi.dev/api/species/22/]</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>2014-12-20T10:26:47.902000Z</td>
#       <td>2014-12-20T21:17:50.427000Z</td>
#       <td>https://swapi.dev/api/people/54/</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Adi Gallia</td>
#       <td>184</td>
#       <td>50</td>
#       <td>none</td>
#       <td>dark</td>
#       <td>blue</td>
#       <td>unknown</td>
#       <td>female</td>
#       <td>https://swapi.dev/api/planets/9/</td>
#       <td>[https://swapi.dev/api/films/4/, https://swapi.dev/api/films/6/]</td>
#       <td>[https://swapi.dev/api/species/23/]</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>2014-12-20T10:29:11.661000Z</td>
#       <td>2014-12-20T21:17:50.432000Z</td>
#       <td>https://swapi.dev/api/people/55/</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Saesee Tiin</td>
#       <td>188</td>
#       <td>unknown</td>
#       <td>none</td>
#       <td>pale</td>
#       <td>orange</td>
#       <td>unknown</td>
#       <td>male</td>
#       <td>https://swapi.dev/api/planets/47/</td>
#       <td>[https://swapi.dev/api/films/4/, https://swapi.dev/api/films/6/]</td>
#       <td>[https://swapi.dev/api/species/24/]</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>2014-12-20T10:32:11.669000Z</td>
#       <td>2014-12-20T21:17:50.434000Z</td>
#       <td>https://swapi.dev/api/people/56/</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Yarael Poof</td>
#       <td>264</td>
#       <td>unknown</td>
#       <td>none</td>
#       <td>white</td>
#       <td>yellow</td>
#       <td>unknown</td>
#       <td>male</td>
#       <td>https://swapi.dev/api/planets/48/</td>
#       <td>[https://swapi.dev/api/films/4/]</td>
#       <td>[https://swapi.dev/api/species/25/]</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>2014-12-20T10:34:48.725000Z</td>
#       <td>2014-12-20T21:17:50.437000Z</td>
#       <td>https://swapi.dev/api/people/57/</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Plo Koon</td>
#       <td>188</td>
#       <td>80</td>
#       <td>none</td>
#       <td>orange</td>
#       <td>black</td>
#       <td>22BBY</td>
#       <td>male</td>
#       <td>https://swapi.dev/api/planets/49/</td>
#       <td>[https://swapi.dev/api/films/4/, https://swapi.dev/api/films/5/, https://swapi.dev/api/films/6/]</td>
#       <td>[https://swapi.dev/api/species/26/]</td>
#       <td>[]</td>
#       <td>[https://swapi.dev/api/starships/48/]</td>
#       <td>2014-12-20T10:49:19.859000Z</td>
#       <td>2014-12-20T21:17:50.439000Z</td>
#       <td>https://swapi.dev/api/people/58/</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Mas Amedda</td>
#       <td>196</td>
#       <td>unknown</td>
#       <td>none</td>
#       <td>blue</td>
#       <td>blue</td>
#       <td>unknown</td>
#       <td>male</td>
#       <td>https://swapi.dev/api/planets/50/</td>
#       <td>[https://swapi.dev/api/films/4/, https://swapi.dev/api/films/5/]</td>
#       <td>[https://swapi.dev/api/species/27/]</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>2014-12-20T10:53:26.457000Z</td>
#       <td>2014-12-20T21:17:50.442000Z</td>
#       <td>https://swapi.dev/api/people/59/</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Gregar Typho</td>
#       <td>185</td>
#       <td>85</td>
#       <td>black</td>
#       <td>dark</td>
#       <td>brown</td>
#       <td>unknown</td>
#       <td>male</td>
#       <td>https://swapi.dev/api/planets/8/</td>
#       <td>[https://swapi.dev/api/films/5/]</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>[https://swapi.dev/api/starships/39/]</td>
#       <td>2014-12-20T11:10:10.381000Z</td>
#       <td>2014-12-20T21:17:50.445000Z</td>
#       <td>https://swapi.dev/api/people/60/</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Cordé</td>
#       <td>157</td>
#       <td>unknown</td>
#       <td>brown</td>
#       <td>light</td>
#       <td>brown</td>
#       <td>unknown</td>
#       <td>female</td>
#       <td>https://swapi.dev/api/planets/8/</td>
#       <td>[https://swapi.dev/api/films/5/]</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>2014-12-20T11:11:39.630000Z</td>
#       <td>2014-12-20T21:17:50.449000Z</td>
#       <td>https://swapi.dev/api/people/61/</td>
#     </tr>
#   </tbody>
# </table>

# %%
#exportando a tabela escrita em html para arquivo html:

# %%
arq = open("tabela_pagina_6.html", "w")
arq = arq.write(html)

# %%
#organizando os dados de cada pessoa

# %%
df.values.tolist()
# Out:
# [['Ki-Adi-Mundi',
#   '198',
#   '82',
#   'white',
#   'pale',
#   'yellow',
#   '92BBY',
#   'male',
#   'https://swapi.dev/api/planets/43/',
#   ['https://swapi.dev/api/films/4/',
#    'https://swapi.dev/api/films/5/',
#    'https://swapi.dev/api/films/6/'],
#   ['https://swapi.dev/api/species/20/'],
#   [],
#   [],
#   '2014-12-20T10:15:32.293000Z',
#   '2014-12-20T21:17:50.422000Z',
#   'https://swapi.dev/api/people/52/'],
#  ['Kit Fisto',
#   '196',
#   '87',
#   'none',
#   'green',
#   'black',
#   'unknown',
#   'male',
#   'https://swapi.dev/api/planets/44/',
#   ['https://swapi.dev/api/films/4/',
#    'https://swapi.dev/api/films/5/',
#    'https://swapi.dev/api/films/6/'],
#   ['https://swapi.dev/api/species/21/'],
#   [],
#   [],
#   '2014-12-20T10:18:57.202000Z',
#   '2014-12-20T21:17:50.424000Z',
#   'https://swapi.dev/api/people/53/'],
#  ['Eeth Koth',
#   '171',
#   'unknown',
#   'black',
#   'brown',
#   'brown',
#   'unknown',
#   'male',
#   'https://swapi.dev/api/planets/45/',
#   ['https://swapi.dev/api/films/4/', 'https://swapi.dev/api/films/6/'],
#   ['https://swapi.dev/api/species/22/'],
#   [],
#   [],
#   '2014-12-20T10:26:47.902000Z',
#   '2014-12-20T21:17:50.427000Z',
#   'https://swapi.dev/api/people/54/'],
#  ['Adi Gallia',
#   '184',
#   '50',
#   'none',
#   'dark',
#   'blue',
#   'unknown',
#   'female',
#   'https://swapi.dev/api/planets/9/',
#   ['https://swapi.dev/api/films/4/', 'https://swapi.dev/api/films/6/'],
#   ['https://swapi.dev/api/species/23/'],
#   [],
#   [],
#   '2014-12-20T10:29:11.661000Z',
#   '2014-12-20T21:17:50.432000Z',
#   'https://swapi.dev/api/people/55/'],
#  ['Saesee Tiin',
#   '188',
#   'unknown',
#   'none',
#   'pale',
#   'orange',
#   'unknown',
#   'male',
#   'https://swapi.dev/api/planets/47/',
#   ['https://swapi.dev/api/films/4/', 'https://swapi.dev/api/films/6/'],
#   ['https://swapi.dev/api/species/24/'],
#   [],
#   [],
#   '2014-12-20T10:32:11.669000Z',
#   '2014-12-20T21:17:50.434000Z',
#   'https://swapi.dev/api/people/56/'],
#  ['Yarael Poof',
#   '264',
#   'unknown',
#   'none',
#   'white',
#   'yellow',
#   'unknown',
#   'male',
#   'https://swapi.dev/api/planets/48/',
#   ['https://swapi.dev/api/films/4/'],
#   ['https://swapi.dev/api/species/25/'],
#   [],
#   [],
#   '2014-12-20T10:34:48.725000Z',
#   '2014-12-20T21:17:50.437000Z',
#   'https://swapi.dev/api/people/57/'],
#  ['Plo Koon',
#   '188',
#   '80',
#   'none',
#   'orange',
#   'black',
#   '22BBY',
#   'male',
#   'https://swapi.dev/api/planets/49/',
#   ['https://swapi.dev/api/films/4/',
#    'https://swapi.dev/api/films/5/',
#    'https://swapi.dev/api/films/6/'],
#   ['https://swapi.dev/api/species/26/'],
#   [],
#   ['https://swapi.dev/api/starships/48/'],
#   '2014-12-20T10:49:19.859000Z',
#   '2014-12-20T21:17:50.439000Z',
#   'https://swapi.dev/api/people/58/'],
#  ['Mas Amedda',
#   '196',
#   'unknown',
#   'none',
#   'blue',
#   'blue',
#   'unknown',
#   'male',
#   'https://swapi.dev/api/planets/50/',
#   ['https://swapi.dev/api/films/4/', 'https://swapi.dev/api/films/5/'],
#   ['https://swapi.dev/api/species/27/'],
#   [],
#   [],
#   '2014-12-20T10:53:26.457000Z',
#   '2014-12-20T21:17:50.442000Z',
#   'https://swapi.dev/api/people/59/'],
#  ['Gregar Typho',
#   '185',
#   '85',
#   'black',
#   'dark',
#   'brown',
#   'unknown',
#   'male',
#   'https://swapi.dev/api/planets/8/',
#   ['https://swapi.dev/api/films/5/'],
#   [],
#   [],
#   ['https://swapi.dev/api/starships/39/'],
#   '2014-12-20T11:10:10.381000Z',
#   '2014-12-20T21:17:50.445000Z',
#   'https://swapi.dev/api/people/60/'],
#  ['Cordé',
#   '157',
#   'unknown',
#   'brown',
#   'light',
#   'brown',
#   'unknown',
#   'female',
#   'https://swapi.dev/api/planets/8/',
#   ['https://swapi.dev/api/films/5/'],
#   [],
#   [],
#   [],
#   '2014-12-20T11:11:39.630000Z',
#   '2014-12-20T21:17:50.449000Z',
#   'https://swapi.dev/api/people/61/']]

# %%
# Página 6
#Catalogando as cores de pele desta página 6:

# %%
cor_da_pele = df[['skin_color']]
display(cor_da_pele)
# Out:
#   skin_color
# 0       pale
# 1      green
# 2      brown
# 3       dark
# 4       pale
# 5      white
# 6     orange
# 7       blue
# 8       dark
# 9      light

# %%
# Página 6
# Organizando a lista das cores de pele

# %%
listacordapele = cor_da_pele ["skin_color"].tolist()
print(listacordapele)
# Out:
# ['pale', 'green', 'brown', 'dark', 'pale', 'white', 'orange', 'blue', 'dark', 'light']

# %%
# Página 6
# Eliminando da lista as cores de pele repetidas:

# %%
cor_da_pele_nao_repetida = {'pale', 'green', 'brown', 'dark', 'pale', 'white', 'orange', 'blue', 'dark', 'light'}
print(cor_da_pele_nao_repetida)
# Out:
# {'orange', 'brown', 'green', 'blue', 'dark', 'white', 'light', 'pale'}
