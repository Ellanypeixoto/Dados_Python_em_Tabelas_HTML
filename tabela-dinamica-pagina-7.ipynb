# %%
import pandas as pd
import numpy as np

# %%
# Página 7 (https://swapi.dev/api/people/?page=7)
# capturando a lista de pessoas, para compor a tabela:

# %%
results_page_7 = [
     {
            "name": "Cliegg Lars", 
            "height": "183", 
            "mass": "unknown", 
            "hair_color": "brown", 
            "skin_color": "fair", 
            "eye_color": "blue", 
            "birth_year": "82BBY", 
            "gender": "male", 
            "homeworld": "https://swapi.dev/api/planets/1/", 
            "films": [
                "https://swapi.dev/api/films/5/"
            ], 
            "species": [], 
            "vehicles": [], 
            "starships": [], 
            "created": "2014-12-20T15:59:03.958000Z", 
            "edited": "2014-12-20T21:17:50.451000Z", 
            "url": "https://swapi.dev/api/people/62/"
        }, 
        {
            "name": "Poggle the Lesser", 
            "height": "183", 
            "mass": "80", 
            "hair_color": "none", 
            "skin_color": "green", 
            "eye_color": "yellow", 
            "birth_year": "unknown", 
            "gender": "male", 
            "homeworld": "https://swapi.dev/api/planets/11/", 
            "films": [
                "https://swapi.dev/api/films/5/", 
                "https://swapi.dev/api/films/6/"
            ], 
            "species": [
                "https://swapi.dev/api/species/28/"
            ], 
            "vehicles": [], 
            "starships": [], 
            "created": "2014-12-20T16:40:43.977000Z", 
            "edited": "2014-12-20T21:17:50.453000Z", 
            "url": "https://swapi.dev/api/people/63/"
        }, 
        {
            "name": "Luminara Unduli", 
            "height": "170", 
            "mass": "56.2", 
            "hair_color": "black", 
            "skin_color": "yellow", 
            "eye_color": "blue", 
            "birth_year": "58BBY", 
            "gender": "female", 
            "homeworld": "https://swapi.dev/api/planets/51/", 
            "films": [
                "https://swapi.dev/api/films/5/", 
                "https://swapi.dev/api/films/6/"
            ], 
            "species": [
                "https://swapi.dev/api/species/29/"
            ], 
            "vehicles": [], 
            "starships": [], 
            "created": "2014-12-20T16:45:53.668000Z", 
            "edited": "2014-12-20T21:17:50.455000Z", 
            "url": "https://swapi.dev/api/people/64/"
        }, 
        {
            "name": "Barriss Offee", 
            "height": "166", 
            "mass": "50", 
            "hair_color": "black", 
            "skin_color": "yellow", 
            "eye_color": "blue", 
            "birth_year": "40BBY", 
            "gender": "female", 
            "homeworld": "https://swapi.dev/api/planets/51/", 
            "films": [
                "https://swapi.dev/api/films/5/"
            ], 
            "species": [
                "https://swapi.dev/api/species/29/"
            ], 
            "vehicles": [], 
            "starships": [], 
            "created": "2014-12-20T16:46:40.440000Z", 
            "edited": "2014-12-20T21:17:50.457000Z", 
            "url": "https://swapi.dev/api/people/65/"
        }, 
        {
            "name": "Dormé", 
            "height": "165", 
            "mass": "unknown", 
            "hair_color": "brown", 
            "skin_color": "light", 
            "eye_color": "brown", 
            "birth_year": "unknown", 
            "gender": "female", 
            "homeworld": "https://swapi.dev/api/planets/8/", 
            "films": [
                "https://swapi.dev/api/films/5/"
            ], 
            "species": [
                "https://swapi.dev/api/species/1/"
            ], 
            "vehicles": [], 
            "starships": [], 
            "created": "2014-12-20T16:49:14.640000Z", 
            "edited": "2014-12-20T21:17:50.460000Z", 
            "url": "https://swapi.dev/api/people/66/"
        }, 
        {
            "name": "Dooku", 
            "height": "193", 
            "mass": "80", 
            "hair_color": "white", 
            "skin_color": "fair", 
            "eye_color": "brown", 
            "birth_year": "102BBY", 
            "gender": "male", 
            "homeworld": "https://swapi.dev/api/planets/52/", 
            "films": [
                "https://swapi.dev/api/films/5/", 
                "https://swapi.dev/api/films/6/"
            ], 
            "species": [
                "https://swapi.dev/api/species/1/"
            ], 
            "vehicles": [
                "https://swapi.dev/api/vehicles/55/"
            ], 
            "starships": [], 
            "created": "2014-12-20T16:52:14.726000Z", 
            "edited": "2014-12-20T21:17:50.462000Z", 
            "url": "https://swapi.dev/api/people/67/"
        }, 
        {
            "name": "Bail Prestor Organa", 
            "height": "191", 
            "mass": "unknown", 
            "hair_color": "black", 
            "skin_color": "tan", 
            "eye_color": "brown", 
            "birth_year": "67BBY", 
            "gender": "male", 
            "homeworld": "https://swapi.dev/api/planets/2/", 
            "films": [
                "https://swapi.dev/api/films/5/", 
                "https://swapi.dev/api/films/6/"
            ], 
            "species": [
                "https://swapi.dev/api/species/1/"
            ], 
            "vehicles": [], 
            "starships": [], 
            "created": "2014-12-20T16:53:08.575000Z", 
            "edited": "2014-12-20T21:17:50.463000Z", 
            "url": "https://swapi.dev/api/people/68/"
        }, 
        {
            "name": "Jango Fett", 
            "height": "183", 
            "mass": "79", 
            "hair_color": "black", 
            "skin_color": "tan", 
            "eye_color": "brown", 
            "birth_year": "66BBY", 
            "gender": "male", 
            "homeworld": "https://swapi.dev/api/planets/53/", 
            "films": [
                "https://swapi.dev/api/films/5/"
            ], 
            "species": [], 
            "vehicles": [], 
            "starships": [], 
            "created": "2014-12-20T16:54:41.620000Z", 
            "edited": "2014-12-20T21:17:50.465000Z", 
            "url": "https://swapi.dev/api/people/69/"
        }, 
        {
            "name": "Zam Wesell", 
            "height": "168", 
            "mass": "55", 
            "hair_color": "blonde", 
            "skin_color": "fair, green, yellow", 
            "eye_color": "yellow", 
            "birth_year": "unknown", 
            "gender": "female", 
            "homeworld": "https://swapi.dev/api/planets/54/", 
            "films": [
                "https://swapi.dev/api/films/5/"
            ], 
            "species": [
                "https://swapi.dev/api/species/30/"
            ], 
            "vehicles": [
                "https://swapi.dev/api/vehicles/45/"
            ], 
            "starships": [], 
            "created": "2014-12-20T16:57:44.471000Z", 
            "edited": "2014-12-20T21:17:50.468000Z", 
            "url": "https://swapi.dev/api/people/70/"
        }, 
        {
            "name": "Dexter Jettster", 
            "height": "198", 
            "mass": "102", 
            "hair_color": "none", 
            "skin_color": "brown", 
            "eye_color": "yellow", 
            "birth_year": "unknown", 
            "gender": "male", 
            "homeworld": "https://swapi.dev/api/planets/55/", 
            "films": [
                "https://swapi.dev/api/films/5/"
            ], 
            "species": [
                "https://swapi.dev/api/species/31/"
            ], 
            "vehicles": [], 
            "starships": [], 
            "created": "2014-12-20T17:28:27.248000Z", 
            "edited": "2014-12-20T21:17:50.470000Z", 
            "url": "https://swapi.dev/api/people/71/"
        }
    ]

# %%
# Página 7
# transformando os dados em dataframe:

# %%
df = pd.DataFrame(results_page_7)

print(df)
# Out:
#                   name height     mass hair_color           skin_color  \
# 0          Cliegg Lars    183  unknown      brown                 fair
# 1    Poggle the Lesser    183       80       none                green
# 2      Luminara Unduli    170     56.2      black               yellow
# 3        Barriss Offee    166       50      black               yellow
# 4                Dormé    165  unknown      brown                light
# 5                Dooku    193       80      white                 fair
# 6  Bail Prestor Organa    191  unknown      black                  tan
# 7           Jango Fett    183       79      black                  tan
# 8           Zam Wesell    168       55     blonde  fair, green, yellow
# 9      Dexter Jettster    198      102       none                brown
#
#   eye_color birth_year  gender                          homeworld  \
# 0      blue      82BBY    male   https://swapi.dev/api/planets/1/
# 1    yellow    unknown    male  https://swapi.dev/api/planets/11/
# 2      blue      58BBY  female  https://swapi.dev/api/planets/51/
# 3      blue      40BBY  female  https://swapi.dev/api/planets/51/
# 4     brown    unknown  female   https://swapi.dev/api/planets/8/
# 5     brown     102BBY    male  https://swapi.dev/api/planets/52/
# 6     brown      67BBY    male   https://swapi.dev/api/planets/2/
# 7     brown      66BBY    male  https://swapi.dev/api/planets/53/
# 8    yellow    unknown  female  https://swapi.dev/api/planets/54/
# 9    yellow    unknown    male  https://swapi.dev/api/planets/55/
#
#                                                films  \
# 0                   [https://swapi.dev/api/films/5/]
# 1  [https://swapi.dev/api/films/5/, https://swapi...
# 2  [https://swapi.dev/api/films/5/, https://swapi...
# 3                   [https://swapi.dev/api/films/5/]
# 4                   [https://swapi.dev/api/films/5/]
# 5  [https://swapi.dev/api/films/5/, https://swapi...
# 6  [https://swapi.dev/api/films/5/, https://swapi...
# 7                   [https://swapi.dev/api/films/5/]
# 8                   [https://swapi.dev/api/films/5/]
# 9                   [https://swapi.dev/api/films/5/]
#
#                                species                              vehicles  \
# 0                                   []                                    []
# 1  [https://swapi.dev/api/species/28/]                                    []
# 2  [https://swapi.dev/api/species/29/]                                    []
# 3  [https://swapi.dev/api/species/29/]                                    []
# 4   [https://swapi.dev/api/species/1/]                                    []
# 5   [https://swapi.dev/api/species/1/]  [https://swapi.dev/api/vehicles/55/]
# 6   [https://swapi.dev/api/species/1/]                                    []
# 7                                   []                                    []
# 8  [https://swapi.dev/api/species/30/]  [https://swapi.dev/api/vehicles/45/]
# 9  [https://swapi.dev/api/species/31/]                                    []
#
#   starships                      created                       edited  \
# 0        []  2014-12-20T15:59:03.958000Z  2014-12-20T21:17:50.451000Z
# 1        []  2014-12-20T16:40:43.977000Z  2014-12-20T21:17:50.453000Z
# 2        []  2014-12-20T16:45:53.668000Z  2014-12-20T21:17:50.455000Z
# 3        []  2014-12-20T16:46:40.440000Z  2014-12-20T21:17:50.457000Z
# 4        []  2014-12-20T16:49:14.640000Z  2014-12-20T21:17:50.460000Z
# 5        []  2014-12-20T16:52:14.726000Z  2014-12-20T21:17:50.462000Z
# 6        []  2014-12-20T16:53:08.575000Z  2014-12-20T21:17:50.463000Z
# 7        []  2014-12-20T16:54:41.620000Z  2014-12-20T21:17:50.465000Z
# 8        []  2014-12-20T16:57:44.471000Z  2014-12-20T21:17:50.468000Z
# 9        []  2014-12-20T17:28:27.248000Z  2014-12-20T21:17:50.470000Z
#
#                                 url
# 0  https://swapi.dev/api/people/62/
# 1  https://swapi.dev/api/people/63/
# 2  https://swapi.dev/api/people/64/
# 3  https://swapi.dev/api/people/65/
# 4  https://swapi.dev/api/people/66/
# 5  https://swapi.dev/api/people/67/
# 6  https://swapi.dev/api/people/68/
# 7  https://swapi.dev/api/people/69/
# 8  https://swapi.dev/api/people/70/
# 9  https://swapi.dev/api/people/71/

# %%
# Página 7
# transformando o dataframe em tabela

# %%
df
# Out:
#                   name height     mass hair_color           skin_color  \
# 0          Cliegg Lars    183  unknown      brown                 fair
# 1    Poggle the Lesser    183       80       none                green
# 2      Luminara Unduli    170     56.2      black               yellow
# 3        Barriss Offee    166       50      black               yellow
# 4                Dormé    165  unknown      brown                light
# 5                Dooku    193       80      white                 fair
# 6  Bail Prestor Organa    191  unknown      black                  tan
# 7           Jango Fett    183       79      black                  tan
# 8           Zam Wesell    168       55     blonde  fair, green, yellow
# 9      Dexter Jettster    198      102       none                brown
#
#   eye_color birth_year  gender                          homeworld  \
# 0      blue      82BBY    male   https://swapi.dev/api/planets/1/
# 1    yellow    unknown    male  https://swapi.dev/api/planets/11/
# 2      blue      58BBY  female  https://swapi.dev/api/planets/51/
# 3      blue      40BBY  female  https://swapi.dev/api/planets/51/
# 4     brown    unknown  female   https://swapi.dev/api/planets/8/
# 5     brown     102BBY    male  https://swapi.dev/api/planets/52/
# 6     brown      67BBY    male   https://swapi.dev/api/planets/2/
# 7     brown      66BBY    male  https://swapi.dev/api/planets/53/
# 8    yellow    unknown  female  https://swapi.dev/api/planets/54/
# 9    yellow    unknown    male  https://swapi.dev/api/planets/55/
#
#                                                films  \
# 0                   [https://swapi.dev/api/films/5/]
# 1  [https://swapi.dev/api/films/5/, https://swapi...
# 2  [https://swapi.dev/api/films/5/, https://swapi...
# 3                   [https://swapi.dev/api/films/5/]
# 4                   [https://swapi.dev/api/films/5/]
# 5  [https://swapi.dev/api/films/5/, https://swapi...
# 6  [https://swapi.dev/api/films/5/, https://swapi...
# 7                   [https://swapi.dev/api/films/5/]
# 8                   [https://swapi.dev/api/films/5/]
# 9                   [https://swapi.dev/api/films/5/]
#
#                                species                              vehicles  \
# 0                                   []                                    []
# 1  [https://swapi.dev/api/species/28/]                                    []
# 2  [https://swapi.dev/api/species/29/]                                    []
# 3  [https://swapi.dev/api/species/29/]                                    []
# 4   [https://swapi.dev/api/species/1/]                                    []
# 5   [https://swapi.dev/api/species/1/]  [https://swapi.dev/api/vehicles/55/]
# 6   [https://swapi.dev/api/species/1/]                                    []
# 7                                   []                                    []
# 8  [https://swapi.dev/api/species/30/]  [https://swapi.dev/api/vehicles/45/]
# 9  [https://swapi.dev/api/species/31/]                                    []
#
#   starships                      created                       edited  \
# 0        []  2014-12-20T15:59:03.958000Z  2014-12-20T21:17:50.451000Z
# 1        []  2014-12-20T16:40:43.977000Z  2014-12-20T21:17:50.453000Z
# 2        []  2014-12-20T16:45:53.668000Z  2014-12-20T21:17:50.455000Z
# 3        []  2014-12-20T16:46:40.440000Z  2014-12-20T21:17:50.457000Z
# 4        []  2014-12-20T16:49:14.640000Z  2014-12-20T21:17:50.460000Z
# 5        []  2014-12-20T16:52:14.726000Z  2014-12-20T21:17:50.462000Z
# 6        []  2014-12-20T16:53:08.575000Z  2014-12-20T21:17:50.463000Z
# 7        []  2014-12-20T16:54:41.620000Z  2014-12-20T21:17:50.465000Z
# 8        []  2014-12-20T16:57:44.471000Z  2014-12-20T21:17:50.468000Z
# 9        []  2014-12-20T17:28:27.248000Z  2014-12-20T21:17:50.470000Z
#
#                                 url
# 0  https://swapi.dev/api/people/62/
# 1  https://swapi.dev/api/people/63/
# 2  https://swapi.dev/api/people/64/
# 3  https://swapi.dev/api/people/65/
# 4  https://swapi.dev/api/people/66/
# 5  https://swapi.dev/api/people/67/
# 6  https://swapi.dev/api/people/68/
# 7  https://swapi.dev/api/people/69/
# 8  https://swapi.dev/api/people/70/
# 9  https://swapi.dev/api/people/71/

# %%
# Página 7
# selecionando os dados solicitados: nome e cor da pele

# %%
nome_e_cor_da_pele = df[['name', 'skin_color']]
display(nome_e_cor_da_pele)
# Out:
#                   name           skin_color
# 0          Cliegg Lars                 fair
# 1    Poggle the Lesser                green
# 2      Luminara Unduli               yellow
# 3        Barriss Offee               yellow
# 4                Dormé                light
# 5                Dooku                 fair
# 6  Bail Prestor Organa                  tan
# 7           Jango Fett                  tan
# 8           Zam Wesell  fair, green, yellow
# 9      Dexter Jettster                brown

# %%
# Página 7
# Colunas com as propriedades e seus respectivos valores, de acordo com o retorno da api nome , altura, peso, aniversário e gênero.

# %%
nome_altura_peso_aniversario_genero = df[['name', 'height', 'mass', 'birth_year', 'gender' ]]
display(nome_altura_peso_aniversario_genero)
# Out:
#                   name height     mass birth_year  gender
# 0          Cliegg Lars    183  unknown      82BBY    male
# 1    Poggle the Lesser    183       80    unknown    male
# 2      Luminara Unduli    170     56.2      58BBY  female
# 3        Barriss Offee    166       50      40BBY  female
# 4                Dormé    165  unknown    unknown  female
# 5                Dooku    193       80     102BBY    male
# 6  Bail Prestor Organa    191  unknown      67BBY    male
# 7           Jango Fett    183       79      66BBY    male
# 8           Zam Wesell    168       55    unknown  female
# 9      Dexter Jettster    198      102    unknown    male

# %%
# transformando a tabela python completa em uma tabela HTML (para construir as páginas)

# %%
html=df.to_html()
print(html)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>height</th>
#       <th>mass</th>
#       <th>hair_color</th>
#       <th>skin_color</th>
#       <th>eye_color</th>
#       <th>birth_year</th>
#       <th>gender</th>
#       <th>homeworld</th>
#       <th>films</th>
#       <th>species</th>
#       <th>vehicles</th>
#       <th>starships</th>
#       <th>created</th>
#       <th>edited</th>
#       <th>url</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Cliegg Lars</td>
#       <td>183</td>
#       <td>unknown</td>
#       <td>brown</td>
#       <td>fair</td>
#       <td>blue</td>
#       <td>82BBY</td>
#       <td>male</td>
#       <td>https://swapi.dev/api/planets/1/</td>
#       <td>[https://swapi.dev/api/films/5/]</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>2014-12-20T15:59:03.958000Z</td>
#       <td>2014-12-20T21:17:50.451000Z</td>
#       <td>https://swapi.dev/api/people/62/</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Poggle the Lesser</td>
#       <td>183</td>
#       <td>80</td>
#       <td>none</td>
#       <td>green</td>
#       <td>yellow</td>
#       <td>unknown</td>
#       <td>male</td>
#       <td>https://swapi.dev/api/planets/11/</td>
#       <td>[https://swapi.dev/api/films/5/, https://swapi.dev/api/films/6/]</td>
#       <td>[https://swapi.dev/api/species/28/]</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>2014-12-20T16:40:43.977000Z</td>
#       <td>2014-12-20T21:17:50.453000Z</td>
#       <td>https://swapi.dev/api/people/63/</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Luminara Unduli</td>
#       <td>170</td>
#       <td>56.2</td>
#       <td>black</td>
#       <td>yellow</td>
#       <td>blue</td>
#       <td>58BBY</td>
#       <td>female</td>
#       <td>https://swapi.dev/api/planets/51/</td>
#       <td>[https://swapi.dev/api/films/5/, https://swapi.dev/api/films/6/]</td>
#       <td>[https://swapi.dev/api/species/29/]</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>2014-12-20T16:45:53.668000Z</td>
#       <td>2014-12-20T21:17:50.455000Z</td>
#       <td>https://swapi.dev/api/people/64/</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Barriss Offee</td>
#       <td>166</td>
#       <td>50</td>
#       <td>black</td>
#       <td>yellow</td>
#       <td>blue</td>
#       <td>40BBY</td>
#       <td>female</td>
#       <td>https://swapi.dev/api/planets/51/</td>
#       <td>[https://swapi.dev/api/films/5/]</td>
#       <td>[https://swapi.dev/api/species/29/]</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>2014-12-20T16:46:40.440000Z</td>
#       <td>2014-12-20T21:17:50.457000Z</td>
#       <td>https://swapi.dev/api/people/65/</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Dormé</td>
#       <td>165</td>
#       <td>unknown</td>
#       <td>brown</td>
#       <td>light</td>
#       <td>brown</td>
#       <td>unknown</td>
#       <td>female</td>
#       <td>https://swapi.dev/api/planets/8/</td>
#       <td>[https://swapi.dev/api/films/5/]</td>
#       <td>[https://swapi.dev/api/species/1/]</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>2014-12-20T16:49:14.640000Z</td>
#       <td>2014-12-20T21:17:50.460000Z</td>
#       <td>https://swapi.dev/api/people/66/</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Dooku</td>
#       <td>193</td>
#       <td>80</td>
#       <td>white</td>
#       <td>fair</td>
#       <td>brown</td>
#       <td>102BBY</td>
#       <td>male</td>
#       <td>https://swapi.dev/api/planets/52/</td>
#       <td>[https://swapi.dev/api/films/5/, https://swapi.dev/api/films/6/]</td>
#       <td>[https://swapi.dev/api/species/1/]</td>
#       <td>[https://swapi.dev/api/vehicles/55/]</td>
#       <td>[]</td>
#       <td>2014-12-20T16:52:14.726000Z</td>
#       <td>2014-12-20T21:17:50.462000Z</td>
#       <td>https://swapi.dev/api/people/67/</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Bail Prestor Organa</td>
#       <td>191</td>
#       <td>unknown</td>
#       <td>black</td>
#       <td>tan</td>
#       <td>brown</td>
#       <td>67BBY</td>
#       <td>male</td>
#       <td>https://swapi.dev/api/planets/2/</td>
#       <td>[https://swapi.dev/api/films/5/, https://swapi.dev/api/films/6/]</td>
#       <td>[https://swapi.dev/api/species/1/]</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>2014-12-20T16:53:08.575000Z</td>
#       <td>2014-12-20T21:17:50.463000Z</td>
#       <td>https://swapi.dev/api/people/68/</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Jango Fett</td>
#       <td>183</td>
#       <td>79</td>
#       <td>black</td>
#       <td>tan</td>
#       <td>brown</td>
#       <td>66BBY</td>
#       <td>male</td>
#       <td>https://swapi.dev/api/planets/53/</td>
#       <td>[https://swapi.dev/api/films/5/]</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>2014-12-20T16:54:41.620000Z</td>
#       <td>2014-12-20T21:17:50.465000Z</td>
#       <td>https://swapi.dev/api/people/69/</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Zam Wesell</td>
#       <td>168</td>
#       <td>55</td>
#       <td>blonde</td>
#       <td>fair, green, yellow</td>
#       <td>yellow</td>
#       <td>unknown</td>
#       <td>female</td>
#       <td>https://swapi.dev/api/planets/54/</td>
#       <td>[https://swapi.dev/api/films/5/]</td>
#       <td>[https://swapi.dev/api/species/30/]</td>
#       <td>[https://swapi.dev/api/vehicles/45/]</td>
#       <td>[]</td>
#       <td>2014-12-20T16:57:44.471000Z</td>
#       <td>2014-12-20T21:17:50.468000Z</td>
#       <td>https://swapi.dev/api/people/70/</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Dexter Jettster</td>
#       <td>198</td>
#       <td>102</td>
#       <td>none</td>
#       <td>brown</td>
#       <td>yellow</td>
#       <td>unknown</td>
#       <td>male</td>
#       <td>https://swapi.dev/api/planets/55/</td>
#       <td>[https://swapi.dev/api/films/5/]</td>
#       <td>[https://swapi.dev/api/species/31/]</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>2014-12-20T17:28:27.248000Z</td>
#       <td>2014-12-20T21:17:50.470000Z</td>
#       <td>https://swapi.dev/api/people/71/</td>
#     </tr>
#   </tbody>
# </table>

# %%
#exportando a tabela escrita em html para arquivo html:

# %%
arq = open("tabela_pagina_7.html", "w")
arq = arq.write(html)

# %%
#organizando os dados de cada pessoa

# %%
df.values.tolist()
# Out:
# [['Cliegg Lars',
#   '183',
#   'unknown',
#   'brown',
#   'fair',
#   'blue',
#   '82BBY',
#   'male',
#   'https://swapi.dev/api/planets/1/',
#   ['https://swapi.dev/api/films/5/'],
#   [],
#   [],
#   [],
#   '2014-12-20T15:59:03.958000Z',
#   '2014-12-20T21:17:50.451000Z',
#   'https://swapi.dev/api/people/62/'],
#  ['Poggle the Lesser',
#   '183',
#   '80',
#   'none',
#   'green',
#   'yellow',
#   'unknown',
#   'male',
#   'https://swapi.dev/api/planets/11/',
#   ['https://swapi.dev/api/films/5/', 'https://swapi.dev/api/films/6/'],
#   ['https://swapi.dev/api/species/28/'],
#   [],
#   [],
#   '2014-12-20T16:40:43.977000Z',
#   '2014-12-20T21:17:50.453000Z',
#   'https://swapi.dev/api/people/63/'],
#  ['Luminara Unduli',
#   '170',
#   '56.2',
#   'black',
#   'yellow',
#   'blue',
#   '58BBY',
#   'female',
#   'https://swapi.dev/api/planets/51/',
#   ['https://swapi.dev/api/films/5/', 'https://swapi.dev/api/films/6/'],
#   ['https://swapi.dev/api/species/29/'],
#   [],
#   [],
#   '2014-12-20T16:45:53.668000Z',
#   '2014-12-20T21:17:50.455000Z',
#   'https://swapi.dev/api/people/64/'],
#  ['Barriss Offee',
#   '166',
#   '50',
#   'black',
#   'yellow',
#   'blue',
#   '40BBY',
#   'female',
#   'https://swapi.dev/api/planets/51/',
#   ['https://swapi.dev/api/films/5/'],
#   ['https://swapi.dev/api/species/29/'],
#   [],
#   [],
#   '2014-12-20T16:46:40.440000Z',
#   '2014-12-20T21:17:50.457000Z',
#   'https://swapi.dev/api/people/65/'],
#  ['Dormé',
#   '165',
#   'unknown',
#   'brown',
#   'light',
#   'brown',
#   'unknown',
#   'female',
#   'https://swapi.dev/api/planets/8/',
#   ['https://swapi.dev/api/films/5/'],
#   ['https://swapi.dev/api/species/1/'],
#   [],
#   [],
#   '2014-12-20T16:49:14.640000Z',
#   '2014-12-20T21:17:50.460000Z',
#   'https://swapi.dev/api/people/66/'],
#  ['Dooku',
#   '193',
#   '80',
#   'white',
#   'fair',
#   'brown',
#   '102BBY',
#   'male',
#   'https://swapi.dev/api/planets/52/',
#   ['https://swapi.dev/api/films/5/', 'https://swapi.dev/api/films/6/'],
#   ['https://swapi.dev/api/species/1/'],
#   ['https://swapi.dev/api/vehicles/55/'],
#   [],
#   '2014-12-20T16:52:14.726000Z',
#   '2014-12-20T21:17:50.462000Z',
#   'https://swapi.dev/api/people/67/'],
#  ['Bail Prestor Organa',
#   '191',
#   'unknown',
#   'black',
#   'tan',
#   'brown',
#   '67BBY',
#   'male',
#   'https://swapi.dev/api/planets/2/',
#   ['https://swapi.dev/api/films/5/', 'https://swapi.dev/api/films/6/'],
#   ['https://swapi.dev/api/species/1/'],
#   [],
#   [],
#   '2014-12-20T16:53:08.575000Z',
#   '2014-12-20T21:17:50.463000Z',
#   'https://swapi.dev/api/people/68/'],
#  ['Jango Fett',
#   '183',
#   '79',
#   'black',
#   'tan',
#   'brown',
#   '66BBY',
#   'male',
#   'https://swapi.dev/api/planets/53/',
#   ['https://swapi.dev/api/films/5/'],
#   [],
#   [],
#   [],
#   '2014-12-20T16:54:41.620000Z',
#   '2014-12-20T21:17:50.465000Z',
#   'https://swapi.dev/api/people/69/'],
#  ['Zam Wesell',
#   '168',
#   '55',
#   'blonde',
#   'fair, green, yellow',
#   'yellow',
#   'unknown',
#   'female',
#   'https://swapi.dev/api/planets/54/',
#   ['https://swapi.dev/api/films/5/'],
#   ['https://swapi.dev/api/species/30/'],
#   ['https://swapi.dev/api/vehicles/45/'],
#   [],
#   '2014-12-20T16:57:44.471000Z',
#   '2014-12-20T21:17:50.468000Z',
#   'https://swapi.dev/api/people/70/'],
#  ['Dexter Jettster',
#   '198',
#   '102',
#   'none',
#   'brown',
#   'yellow',
#   'unknown',
#   'male',
#   'https://swapi.dev/api/planets/55/',
#   ['https://swapi.dev/api/films/5/'],
#   ['https://swapi.dev/api/species/31/'],
#   [],
#   [],
#   '2014-12-20T17:28:27.248000Z',
#   '2014-12-20T21:17:50.470000Z',
#   'https://swapi.dev/api/people/71/']]

# %%
# Página 7
#Catalogando as cores de pele desta página 7:

# %%
cor_da_pele = df[['skin_color']]
display(cor_da_pele)
# Out:
#             skin_color
# 0                 fair
# 1                green
# 2               yellow
# 3               yellow
# 4                light
# 5                 fair
# 6                  tan
# 7                  tan
# 8  fair, green, yellow
# 9                brown

# %%
# Página 7
# Organizando a lista das cores de pele

# %%
listacordapele = cor_da_pele ["skin_color"].tolist()
print(listacordapele)
# Out:
# ['fair', 'green', 'yellow', 'yellow', 'light', 'fair', 'tan', 'tan', 'fair, green, yellow', 'brown']

# %%
# Página 7
# Eliminando da lista as cores de pele repetidas:

# %%
cor_da_pele_nao_repetida = {'fair', 'green', 'yellow', 'yellow', 'light', 'fair', 'tan', 'tan', 'fair, green, yellow', 'brown'}
print(cor_da_pele_nao_repetida)
# Out:
# {'green', 'fair, green, yellow', 'brown', 'yellow', 'light', 'fair', 'tan'}
